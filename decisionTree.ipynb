# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import csv
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
from sklearn.metrics import mean_squared_error 
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.tree import plot_tree

# %% [markdown]
# # Importing and Splitting data

# %%
modelEncoder = LabelEncoder()
transmissionEncoder = LabelEncoder()
fuelTypeEncoder = LabelEncoder()

def dataset(brand):

    file = pd.read_csv(brand, quotechar='"', skipinitialspace=True)

    modelEncoder.fit(file["model"])
    file["model"] = modelEncoder.transform(file["model"])

    transmissionEncoder.fit(file["transmission"])
    file["transmission"] = transmissionEncoder.transform(file["transmission"])

    fuelTypeEncoder.fit(file["fuelType"])
    file["fuelType"] = fuelTypeEncoder.transform(file["fuelType"])

    file = file.head(1000)
    # X = file.drop(columns = ['price'])
    # Y = file.price
    # print(file)

    X = file.drop(['price'], axis = 1).to_numpy()
    # X = file[['year', 'mileage', 'tax', 'mpg', 'engineSize']].to_numpy(dtype = 'int')
    Y = file['price'].values.reshape(-1,1)

#     print(X)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 601)
    
    return  X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = dataset("UKUsedCarDataSet/audi.csv") # Use Audi dataset as default for KNN analysis

# %% [markdown]
# # Using Scikit-Learn

# %%
myTree = DecisionTreeRegressor(random_state = 601, max_depth = 5, min_samples_split = 3) #, max_depth = 3
myTree.fit(X_train, Y_train)
print("R Squared: ", myTree.score(X_test, Y_test))
#92, 3 = 0.8593705968859954
#5, 3 = 0.7566846373060692
# Out:
# R Squared:  0.7566846373060692

# %% [markdown]
# # GridSeacrhCV to find optimal parameters

# %%
from sklearn.model_selection import GridSearchCV

# params = {'min_samples_split': [2, 3, 4], 'max_leaf_nodes': list(range(2, 100)), 'max_depth': list(range(1, 100))} #'max_leaf_nodes': list(range(2, 100)),
params = {'min_samples_split': [3, 4, 5, 6], 'max_depth': list(range(1, 6)), 'max_leaf_nodes': list(range(2, 6))}
grid_search_cv = GridSearchCV(myTree, params, cv=3)
grid_search_cv.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=DecisionTreeRegressor(max_depth=11, min_samples_split=3,
#                                              random_state=601),
#              param_grid={'max_depth': [1, 2, 3, 4, 5],
#                          'max_leaf_nodes': [2, 3, 4, 5],
#                          'min_samples_split': [3, 4, 5, 6]})

# %%
grid_search_cv.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=3, max_leaf_nodes=5, min_samples_split=3,
#                       random_state=601)

# %% [markdown]
# # Visualising Decsion Tree:

# %% [markdown]
# X1 = file.drop(['price'], axis = 1)
#
# plt.figure(figsize=(20, 10), dpi = 200)
# plot_tree(myTree, feature_names = X1.columns, filled=True);

# %% [markdown]
# # RMSE

# %%
def rmse(h, y):
  return sqrt(mean_squared_error(h, y))

# %% [markdown]
# # Node Class

# %%
# Node class to initialise instances of each 
class Node():
    
    def __init__(self, feature = None, limit = None, leftSide = None, rightSide = None, gain = None, leaf = None):
        
        self.feature = feature
        self.limit = limit
        self.leftSide = leftSide
        self.rightSide = rightSide
        self.gain = gain
        self.leaf = leaf

# %% [markdown]
# # Decision Tree Regression Class

# %%
class DTRegressor():
    def __init__(self, minSamples, maxDepth):
        self.root = None
        self.minSamples = minSamples
        self.maxDepth = maxDepth
        
    def infoGain(self, parent, leftNode, rightNode):
        leftWeight = len(leftNode) / len(parent)
        rightWeight = len(rightNode) / len(parent)
        
        information_gain = np.var(parent) - (leftWeight * np.var(leftNode) + rightWeight * np.var(rightNode))

        return information_gain
        
    def splitTree(self, trainingSet, feature, limit):
        leftBranch = []
        rightBranch = []
        for i in trainingSet:
            if i[feature] <= limit:
                leftBranch.append(i)
            else:
                rightBranch.append(i)
        rightBranch = np.array(rightBranch)
        leftBranch = np.array(leftBranch)
        return leftBranch, rightBranch
        
    def bestSplit(self, trainingSet, X):
        bestSplitt = {} 
        biggestGain = -1
        for feature in range(X.shape[1]): 
#             featureValues = trainingSet[:, feature] #current feature selected
            featureValues = []
            for i in range(len(trainingSet)):
                featureValues.append(trainingSet[i, feature])
            thresholds = np.unique(featureValues)
            for j in thresholds: #j = threshold
                leftSide, rightSide = self.splitTree(trainingSet, feature, j) #splits node into 2 sub-trees
                if (len(leftSide) > 0 and len(rightSide) > 0 ):
                    parent = []
                    for i in range(len(trainingSet)):
                        parent.append(trainingSet[i, -1])

                    leftNode = []
                    for i in range(len(leftSide)):
                        leftNode.append(leftSide[i, -1])
                        
                    rightNode = []
                    for i in range(len(rightSide)):
                        rightNode.append(rightSide[i, -1])

                    currentGain = self.infoGain(parent, leftNode, rightNode) 
                    if currentGain > biggestGain:
                        
                        bestSplitt["feature"] = feature
                        bestSplitt["limit"] = j
                        bestSplitt["leftSide"] = leftSide
                        bestSplitt["rightSide"] = rightSide
                        bestSplitt["gain"] = currentGain
                        biggestGain = currentGain
                
        return bestSplitt
   
        
    def treeBuild(self, trainingSet, currentDepth = 0):
        
#       #Split training into features and labels
        X = trainingSet[:,:-1] # everything but the last value
        Y = []
        for i in range(len(trainingSet)):
            Y.append(trainingSet[i, -1])# only the last value
        
        #iterates until this condition is met
        if X.shape[0] >= self.minSamples and currentDepth <= self.maxDepth:
#             bestSplit = self.bestSplit(trainingSet, samplesNumb, featuresNumb)
            bestSplitNode = self.bestSplit(trainingSet, X)
            
            if bestSplitNode["gain"] > 0:
                leftTree = self.treeBuild(bestSplitNode["leftSide"], currentDepth + 1)
                rightTree = self.treeBuild(bestSplitNode["rightSide"], currentDepth + 1)
                node = Node(bestSplitNode["feature"], bestSplitNode["limit"], leftTree, rightTree, bestSplitNode["gain"])
                
                return node
        
        leafValue = np.mean(Y) #calculates mean of leaf nodes
        val = Node(leaf = leafValue)
        return val
    
    def predictionLoop(self, testRow, root):
        if root.leaf != None: #not empty
            return root.leaf
        
        featureVal = testRow[root.feature]
        if featureVal <= root.limit:
            return self.predictionLoop(testRow, root.leftSide)
        else:
            return self.predictionLoop(testRow, root.rightSide)
        
   
    def predict(self, xTest):
        predictions = []
        for row in xTest:
            predictions.append(self.predictionLoop(row, self.root)) 
        return predictions

        
        
    def fit(self, X, Y):
        print(Y)
        trainingSet = np.concatenate((X, Y), axis=1) #Joins training data back together
        self.root = self.treeBuild(trainingSet)

# %% [markdown]
# # Training the algorithm

# %%
myTree = DTRegressor(3, 11) #then 92 
myTree.fit(X_train, Y_train) #trains the model using the training set
# Out:
# [[13250]
#  [12500]
#  [29485]
#  [17988]
#  [12998]
#  [18990]
#  [17498]
#  [33995]
#  [16995]
#  [29985]
#  [13495]
#  [16500]
#  [11998]
#  [21995]
#  [37395]
#  [41495]
#  [31265]
#  [13900]
#  [12000]
#  [25498]
#  [23377]
#  [22500]
#  [19990]
#  [40990]
#  [22990]
#  [46000]
#  [15888]
#  [40780]
#  [45485]
#  [16495]
#  [31985]
#  [15000]
#  [14995]
#  [18998]
#  [31995]
#  [11700]
#  [11990]
#  [34995]
#  [18490]
#  [26990]
#  [24400]
#  [31998]
#  [16500]
#  [19498]
#  [17300]
#  [21995]
#  [19990]
#  [21995]
#  [16498]
#  [ 9800]
#  [37985]
#  [20498]
#  [25000]
#  [22995]
#  [12490]
#  [15995]
#  [15590]
#  [13995]
#  [29490]
#  [20000]
#  [29990]
#  [13100]
#  [22995]
#  [26495]
#  [23995]
#  [15498]
#  [38534]
#  [29985]
#  [16995]
#  [13100]
#  [12995]
#  [11495]
#  [20000]
#  [18995]
#  [26846]
#  [37560]
#  [13995]
#  [14500]
#  [15995]
#  [14998]
#  [18998]
#  [25995]
#  [26485]
#  [23495]
#  [ 9698]
#  [30990]
#  [17985]
#  [17500]
#  [22998]
#  [26588]
#  [18500]
#  [34985]
#  [13995]
#  [10200]
#  [16985]
#  [15498]
#  [18298]
#  [11000]
#  [27985]
#  [33444]
#  [17298]
#  [30995]
#  [15495]
#  [18995]
#  [24485]
#  [36995]
#  [17995]
#  [35995]
#  [18700]
#  [40995]
#  [36312]
#  [38995]
#  [27990]
#  [14495]
#  [82995]
#  [31995]
#  [18998]
#  [20985]
#  [31288]
#  [18695]
#  [18995]
#  [19995]
#  [30995]
#  [18288]
#  [20488]
#  [14995]
#  [20995]
#  [17998]
#  [13800]
#  [46990]
#  [11798]
#  [23995]
#  [16995]
#  [19998]
#  [30985]
#  [20485]
#  [17698]
#  [19500]
#  [69995]
#  [18995]
#  [28985]
#  [14990]
#  [14995]
#  [15498]
#  [18698]
#  [21995]
#  [24444]
#  [17300]
#  [28985]
#  [31985]
#  [17100]
#  [16498]
#  [34985]
#  [10800]
#  [15000]
#  [15498]
#  [34995]
#  [18490]
#  [11500]
#  [31695]
#  [27985]
#  [37331]
#  [12995]
#  [26985]
#  [62985]
#  [11495]
#  [14849]
#  [28888]
#  [19995]
#  [37500]
#  [21888]
#  [27995]
#  [22995]
#  [27995]
#  [16600]
#  [29985]
#  [27995]
#  [49995]
#  [19495]
#  [19995]
#  [12300]
#  [22998]
#  [17498]
#  [15998]
#  [16900]
#  [15995]
#  [14800]
#  [14995]
#  [15995]
#  [19000]
#  [20000]
#  [24985]
#  [20995]
#  [39995]
#  [28495]
#  [19995]
#  [17995]
#  [28985]
#  [22997]
#  [13795]
#  [53939]
#  [22590]
#  [17498]
#  [11995]
#  [19995]
#  [21498]
#  [24995]
#  [19685]
#  [11995]
#  [25998]
#  [21995]
#  [26995]
#  [16998]
#  [13995]
#  [10994]
#  [35995]
#  [28995]
#  [24995]
#  [12995]
#  [29995]
#  [18750]
#  [32985]
#  [18995]
#  [16495]
#  [41995]
#  [16200]
#  [12100]
#  [25995]
#  [29985]
#  [21495]
#  [31500]
#  [10600]
#  [14995]
#  [19995]
#  [10202]
#  [15500]
#  [14700]
#  [36202]
#  [11998]
#  [33995]
#  [28995]
#  [24995]
#  [26011]
#  [27990]
#  [19888]
#  [11490]
#  [25998]
#  [19995]
#  [29995]
#  [13995]
#  [44985]
#  [14298]
#  [16995]
#  [14700]
#  [24985]
#  [38495]
#  [16995]
#  [30197]
#  [17498]
#  [17100]
#  [13998]
#  [11995]
#  [14800]
#  [24985]
#  [25499]
#  [12700]
#  [10500]
#  [19995]
#  [22495]
#  [11700]
#  [36995]
#  [16000]
#  [30985]
#  [15500]
#  [24490]
#  [31795]
#  [ 9500]
#  [13000]
#  [19600]
#  [15498]
#  [26985]
#  [29490]
#  [12995]
#  [24498]
#  [28495]
#  [24888]
#  [16985]
#  [11995]
#  [22995]
#  [16498]
#  [26508]
#  [20495]
#  [20500]
#  [ 7000]
#  [17800]
#  [12990]
#  [37985]
#  [10988]
#  [28985]
#  [30995]
#  [18485]
#  [16995]
#  [22995]
#  [30985]
#  [32485]
#  [34798]
#  [12500]
#  [26000]
#  [19995]
#  [31700]
#  [33500]
#  [19995]
#  [17500]
#  [25444]
#  [21499]
#  [34995]
#  [16500]
#  [38995]
#  [21995]
#  [23685]
#  [30861]
#  [15998]
#  [22485]
#  [31000]
#  [13995]
#  [43495]
#  [14700]
#  [20888]
#  [12000]
#  [16995]
#  [63985]
#  [17995]
#  [11995]
#  [20000]
#  [18998]
#  [50000]
#  [11850]
#  [18000]
#  [13998]
#  [ 8300]
#  [28485]
#  [31985]
#  [42000]
#  [18995]
#  [17995]
#  [31495]
#  [13300]
#  [27995]
#  [30719]
#  [20495]
#  [20995]
#  [12500]
#  [13495]
#  [16000]
#  [15700]
#  [15395]
#  [22988]
#  [13500]
#  [35995]
#  [10985]
#  [19995]
#  [29985]
#  [22995]
#  [32098]
#  [15495]
#  [30985]
#  [37000]
#  [38888]
#  [14000]
#  [18995]
#  [14898]
#  [16490]
#  [57995]
#  [14995]
#  [16000]
#  [12485]
#  [10998]
#  [18998]
#  [19485]
#  [21800]
#  [30728]
#  [19995]
#  [48995]
#  [22495]
#  [33245]
#  [39888]
#  [26995]
#  [14998]
#  [17298]
#  [37000]
#  [58995]
#  [12595]
#  [12995]
#  [14500]
#  [13995]
#  [36985]
#  [39995]
#  [18495]
#  [46985]
#  [20200]
#  [13995]
#  [34995]
#  [11000]
#  [18100]
#  [16498]
#  [26490]
#  [16600]
#  [37995]
#  [13995]
#  [19995]
#  [23700]
#  [31998]
#  [31985]
#  [17000]
#  [15795]
#  [19990]
#  [24998]
#  [16485]
#  [16498]
#  [12950]
#  [12490]
#  [13498]
#  [31995]
#  [29995]
#  [21985]
#  [14995]
#  [10800]
#  [43785]
#  [16498]
#  [39995]
#  [ 9400]
#  [11498]
#  [34995]
#  [21495]
#  [29998]
#  [29985]
#  [20485]
#  [23995]
#  [38995]
#  [39985]
#  [12995]
#  [23998]
#  [19485]
#  [21488]
#  [13998]
#  [29995]
#  [29695]
#  [18495]
#  [14000]
#  [22990]
#  [13900]
#  [16100]
#  [19100]
#  [15000]
#  [12995]
#  [15900]
#  [29485]
#  [ 9498]
#  [13995]
#  [20688]
#  [29888]
#  [30000]
#  [17495]
#  [12500]
#  [20985]
#  [37995]
#  [19995]
#  [19995]
#  [35995]
#  [33295]
#  [31995]
#  [18350]
#  [19495]
#  [47895]
#  [29809]
#  [17498]
#  [48995]
#  [22888]
#  [15498]
#  [26490]
#  [14998]
#  [13995]
#  [35985]
#  [16998]
#  [16998]
#  [18498]
#  [14995]
#  [58990]
#  [41995]
#  [10600]
#  [10600]
#  [16498]
#  [13900]
#  [22995]
#  [19498]
#  [19995]
#  [22995]
#  [16998]
#  [13200]
#  [27995]
#  [32895]
#  [29485]
#  [20995]
#  [19998]
#  [30985]
#  [33985]
#  [33498]
#  [28000]
#  [35995]
#  [15995]
#  [18495]
#  [14698]
#  [ 8498]
#  [28985]
#  [19945]
#  [33410]
#  [14495]
#  [22750]
#  [28995]
#  [38995]
#  [13498]
#  [12698]
#  [30995]
#  [12750]
#  [35495]
#  [15995]
#  [25998]
#  [35995]
#  [23485]
#  [12495]
#  [19400]
#  [45000]
#  [17995]
#  [18495]
#  [32250]
#  [17495]
#  [17985]
#  [16498]
#  [16400]
#  [31500]
#  [18488]
#  [36990]
#  [33995]
#  [21288]
#  [27995]
#  [25995]
#  [22695]
#  [20990]
#  [17995]
#  [18950]
#  [11798]
#  [19940]
#  [15998]
#  [18498]
#  [12995]
#  [19000]
#  [35995]
#  [20000]
#  [24985]
#  [22500]
#  [34485]
#  [11200]
#  [19698]
#  [35995]
#  [13495]
#  [39700]
#  [14000]
#  [83995]
#  [14695]
#  [19995]
#  [18995]
#  [31985]
#  [18000]
#  [19688]
#  [11750]
#  [15800]
#  [19800]
#  [30995]
#  [12485]
#  [13400]
#  [20985]
#  [33444]
#  [16600]
#  [21698]
#  [30888]
#  [23995]
#  [10498]
#  [34995]
#  [19995]
#  [19995]
#  [16798]
#  [16400]
#  [10698]
#  [26995]
#  [19990]
#  [10398]
#  [35888]
#  [50414]
#  [11950]
#  [16500]
#  [10600]
#  [17698]
#  [20300]
#  [13995]
#  [19850]
#  [38995]
#  [12995]
#  [42995]
#  [24998]
#  [17400]
#  [16200]
#  [17000]
#  [31000]
#  [13998]
#  [30995]
#  [15400]
#  [33000]
#  [16490]
#  [31985]
#  [24495]
#  [24995]
#  [11400]
#  [43885]
#  [27985]
#  [46000]
#  [23998]
#  [13995]
#  [19995]
#  [15400]
#  [17500]
#  [14998]
#  [31888]
#  [18499]
#  [18998]
#  [16500]
#  [15400]
#  [25995]
#  [22500]
#  [15998]
#  [31990]
#  [18498]
#  [13998]
#  [38995]
#  [11000]
#  [24368]
#  [11998]
#  [11498]
#  [13585]
#  [25499]
#  [21995]
#  [14495]
#  [11498]
#  [29995]
#  [15500]
#  [16800]
#  [17300]
#  [11695]
#  [12995]
#  [12800]
#  [28495]
#  [13985]
#  [28995]
#  [12298]
#  [22890]
#  [11300]
#  [35995]
#  [15800]
#  [23495]
#  [13998]
#  [20498]
#  [14995]
#  [49985]
#  [18998]
#  [56985]
#  [11698]
#  [10495]
#  [24498]
#  [11995]
#  [25750]
#  [20488]
#  [13498]
#  [23995]
#  [15995]
#  [18495]
#  [31998]
#  [14500]
#  [14498]
#  [28995]
#  [20995]
#  [19995]
#  [28990]
#  [14995]
#  [18500]
#  [33462]
#  [27995]
#  [17000]
#  [33995]
#  [15495]
#  [17998]
#  [34995]
#  [31995]
#  [ 8300]
#  [19495]
#  [18500]
#  [16000]
#  [15995]
#  [17498]
#  [17998]
#  [34995]
#  [33495]
#  [33995]
#  [ 9995]
#  [26995]
#  [20485]
#  [21985]
#  [23995]
#  [41995]
#  [34985]
#  [34998]
#  [11500]
#  [30864]
#  [39995]
#  [11750]
#  [14400]
#  [19998]
#  [17795]
#  [16000]
#  [22288]
#  [19995]
#  [13995]
#  [11698]
#  [16995]
#  [38900]
#  [14495]
#  [39995]
#  [55500]
#  [26000]
#  [23985]
#  [12500]
#  [26500]
#  [10385]
#  [17495]
#  [38985]
#  [15995]
#  [22000]
#  [52985]
#  [21995]
#  [27985]
#  [23995]
#  [11698]]

# %% [markdown]
# # Evaluation

# %%
def evaluation(train, test, yTrain, yTest):    
    y_pred = myTree.predict(X_test)
    print(y_pred)
    error = rmse(yTest, y_pred) 
    print('The RMSE value is:', error)
    for i in range(len(y_pred)):
        print("\nOriginal value:", yTest[i], "vs the predicted value:", y_pred[i])
        print("The difference is:", yTest[i] - y_pred[i])
evaluation(X_train, X_test, Y_train, Y_test)
# Old RMSE value was 5486.187742617547
#4355.8298808608215
#4331.929325238453 with 11
#5050.108048448073 with entropy method
# Out:
# [19267.65811966 19267.65811966 35079.175      13870.02654867
#  22574.5        15975.55084746 19483.17647059 15975.55084746
#  13870.02654867 51652.41666667 13870.02654867 51652.41666667
#  30839.35294118 19483.17647059 35079.175      35079.175
#  27547.05263158 22574.5        19267.65811966 15975.55084746
#  19483.17647059 26979.5        15975.55084746 35079.175
#  19267.65811966 26979.5        28879.4375     15975.55084746
#  30839.35294118 19267.65811966 13870.02654867 13870.02654867
#  13870.02654867 13870.02654867 19267.65811966 30839.35294118
#  19267.65811966 13870.02654867 11112.36666667 15975.55084746
#  22574.5        13870.02654867 15975.55084746 15975.55084746
#  41080.45       13870.02654867 28879.4375     18343.75
#  13870.02654867 15975.55084746 15975.55084746 15975.55084746
#  13870.02654867 15975.55084746 13870.02654867 22574.5
#  20740.         19267.65811966 19267.65811966 27547.05263158
#  15975.55084746 22574.5        19267.65811966 35079.175
#  35079.175      19267.65811966 27547.05263158 15975.55084746
#  15975.55084746 13870.02654867 19267.65811966 15975.55084746
#  11112.36666667 15975.55084746 41080.45       13870.02654867
#  15975.55084746 11112.36666667 35079.175      15975.55084746
#  26979.5        51652.41666667 28879.4375     19483.17647059
#  15975.55084746 19267.65811966 22574.5        28905.85714286
#  19483.17647059 15975.55084746 51652.41666667 13870.02654867
#  19483.17647059 13870.02654867 19267.65811966 13870.02654867
#  26979.5        51652.41666667 13870.02654867 19483.17647059
#  15975.55084746 30839.35294118 26979.5        30839.35294118
#  27547.05263158 19483.17647059 13870.02654867 35079.175
#  41080.45       13870.02654867 19267.65811966 19483.17647059
#  19267.65811966 13870.02654867 19483.17647059 19483.17647059
#  30839.35294118 19267.65811966 41080.45       35079.175
#  26979.5        15975.55084746 26979.5        19483.17647059
#  15975.55084746 30839.35294118 35079.175      51652.41666667
#  35079.175      22574.5        19267.65811966 13870.02654867
#  13870.02654867 35079.175      38518.66666667 15975.55084746
#  36692.57142857 51652.41666667 30839.35294118 19267.65811966
#  22574.5        41080.45       30839.35294118 19267.65811966
#  11112.36666667 22574.5        11112.36666667 13870.02654867
#  19267.65811966 13870.02654867 19483.17647059 27547.05263158
#  19267.65811966 19267.65811966 25478.         35079.175
#  19267.65811966 19267.65811966 19483.17647059 19267.65811966
#  15975.55084746 15975.55084746 13870.02654867 22574.5
#  19267.65811966 30839.35294118 13870.02654867 19267.65811966
#  19267.65811966 13870.02654867 51652.41666667 15975.55084746
#  35079.175      26979.5        28879.4375     35079.175
#  13870.02654867 30839.35294118 19267.65811966 19267.65811966
#  19267.65811966 19267.65811966 15975.55084746 15975.55084746
#  28879.4375     19267.65811966 19267.65811966 18343.75
#  30839.35294118 30839.35294118 28879.4375     15975.55084746
#  28879.4375     15975.55084746 19267.65811966 15975.55084746
#  15975.55084746 15975.55084746 13870.02654867 26979.5
#  15975.55084746 19267.65811966 18343.75       15975.55084746
#  28879.4375     28879.4375     30839.35294118 30839.35294118
#  35079.175      13870.02654867 30839.35294118 41080.45
#  28879.4375     35079.175      19267.65811966 15975.55084746
#  15975.55084746 13870.02654867 30839.35294118 19483.17647059
#  19267.65811966 35079.175      22574.5        13870.02654867
#  13870.02654867 19267.65811966 15975.55084746 44843.125
#  13870.02654867 19483.17647059 19483.17647059 35079.175
#  26979.5        15975.55084746 51652.41666667 13870.02654867
#  28879.4375     51652.41666667 19483.17647059 27547.05263158
#  13870.02654867 38518.66666667 11112.36666667 44843.125
#  22574.5        30839.35294118 19267.65811966 22574.5
#  26979.5        13870.02654867]
# The RMSE value is: 5140.0340781504565
#
# Original value: [18498] vs the predicted value: 19267.65811965812
# The difference is: [-769.65811966]
#
# Original value: [22995] vs the predicted value: 19267.65811965812
# The difference is: [3727.34188034]
#
# Original value: [12495] vs the predicted value: 35079.175
# The difference is: [-22584.175]
#
# Original value: [14500] vs the predicted value: 13870.026548672566
# The difference is: [629.97345133]
#
# Original value: [24995] vs the predicted value: 22574.5
# The difference is: [2420.5]
#
# Original value: [10200] vs the predicted value: 15975.550847457627
# The difference is: [-5775.55084746]
#
# Original value: [21995] vs the predicted value: 19483.176470588234
# The difference is: [2511.82352941]
#
# Original value: [16800] vs the predicted value: 15975.550847457627
# The difference is: [824.44915254]
#
# Original value: [12798] vs the predicted value: 13870.026548672566
# The difference is: [-1072.02654867]
#
# Original value: [20498] vs the predicted value: 51652.416666666664
# The difference is: [-31154.41666667]
#
# Original value: [11498] vs the predicted value: 13870.026548672566
# The difference is: [-2372.02654867]
#
# Original value: [48136] vs the predicted value: 51652.416666666664
# The difference is: [-3516.41666667]
#
# Original value: [32485] vs the predicted value: 30839.352941176472
# The difference is: [1645.64705882]
#
# Original value: [17490] vs the predicted value: 19483.176470588234
# The difference is: [-1993.17647059]
#
# Original value: [33985] vs the predicted value: 35079.175
# The difference is: [-1094.175]
#
# Original value: [36888] vs the predicted value: 35079.175
# The difference is: [1808.825]
#
# Original value: [31995] vs the predicted value: 27547.052631578947
# The difference is: [4447.94736842]
#
# Original value: [23374] vs the predicted value: 22574.5
# The difference is: [799.5]
#
# Original value: [19498] vs the predicted value: 19267.65811965812
# The difference is: [230.34188034]
#
# Original value: [13450] vs the predicted value: 15975.550847457627
# The difference is: [-2525.55084746]
#
# Original value: [23995] vs the predicted value: 19483.176470588234
# The difference is: [4511.82352941]
#
# Original value: [23998] vs the predicted value: 26979.5
# The difference is: [-2981.5]
#
# Original value: [21995] vs the predicted value: 15975.550847457627
# The difference is: [6019.44915254]
#
# Original value: [37985] vs the predicted value: 35079.175
# The difference is: [2905.825]
#
# Original value: [18995] vs the predicted value: 19267.65811965812
# The difference is: [-272.65811966]
#
# Original value: [30709] vs the predicted value: 26979.5
# The difference is: [3729.5]
#
# Original value: [22998] vs the predicted value: 28879.4375
# The difference is: [-5881.4375]
#
# Original value: [17300] vs the predicted value: 15975.550847457627
# The difference is: [1324.44915254]
#
# Original value: [31985] vs the predicted value: 30839.352941176472
# The difference is: [1145.64705882]
#
# Original value: [14900] vs the predicted value: 19267.65811965812
# The difference is: [-4367.65811966]
#
# Original value: [13995] vs the predicted value: 13870.026548672566
# The difference is: [124.97345133]
#
# Original value: [10995] vs the predicted value: 13870.026548672566
# The difference is: [-2875.02654867]
#
# Original value: [13500] vs the predicted value: 13870.026548672566
# The difference is: [-370.02654867]
#
# Original value: [12995] vs the predicted value: 13870.026548672566
# The difference is: [-875.02654867]
#
# Original value: [19995] vs the predicted value: 19267.65811965812
# The difference is: [727.34188034]
#
# Original value: [33640] vs the predicted value: 30839.352941176472
# The difference is: [2800.64705882]
#
# Original value: [19998] vs the predicted value: 19267.65811965812
# The difference is: [730.34188034]
#
# Original value: [14995] vs the predicted value: 13870.026548672566
# The difference is: [1124.97345133]
#
# Original value: [11698] vs the predicted value: 11112.366666666667
# The difference is: [585.63333333]
#
# Original value: [24495] vs the predicted value: 15975.550847457627
# The difference is: [8519.44915254]
#
# Original value: [28062] vs the predicted value: 22574.5
# The difference is: [5487.5]
#
# Original value: [11000] vs the predicted value: 13870.026548672566
# The difference is: [-2870.02654867]
#
# Original value: [11500] vs the predicted value: 15975.550847457627
# The difference is: [-4475.55084746]
#
# Original value: [12000] vs the predicted value: 15975.550847457627
# The difference is: [-3975.55084746]
#
# Original value: [45995] vs the predicted value: 41080.45
# The difference is: [4914.55]
#
# Original value: [14495] vs the predicted value: 13870.026548672566
# The difference is: [624.97345133]
#
# Original value: [24998] vs the predicted value: 28879.4375
# The difference is: [-3881.4375]
#
# Original value: [18498] vs the predicted value: 18343.75
# The difference is: [154.25]
#
# Original value: [7898] vs the predicted value: 13870.026548672566
# The difference is: [-5972.02654867]
#
# Original value: [18295] vs the predicted value: 15975.550847457627
# The difference is: [2319.44915254]
#
# Original value: [16798] vs the predicted value: 15975.550847457627
# The difference is: [822.44915254]
#
# Original value: [21100] vs the predicted value: 15975.550847457627
# The difference is: [5124.44915254]
#
# Original value: [12990] vs the predicted value: 13870.026548672566
# The difference is: [-880.02654867]
#
# Original value: [11950] vs the predicted value: 15975.550847457627
# The difference is: [-4025.55084746]
#
# Original value: [16485] vs the predicted value: 13870.026548672566
# The difference is: [2614.97345133]
#
# Original value: [22495] vs the predicted value: 22574.5
# The difference is: [-79.5]
#
# Original value: [16000] vs the predicted value: 20740.0
# The difference is: [-4740.]
#
# Original value: [16995] vs the predicted value: 19267.65811965812
# The difference is: [-2272.65811966]
#
# Original value: [19995] vs the predicted value: 19267.65811965812
# The difference is: [727.34188034]
#
# Original value: [24500] vs the predicted value: 27547.052631578947
# The difference is: [-3047.05263158]
#
# Original value: [13985] vs the predicted value: 15975.550847457627
# The difference is: [-1990.55084746]
#
# Original value: [20888] vs the predicted value: 22574.5
# The difference is: [-1686.5]
#
# Original value: [19995] vs the predicted value: 19267.65811965812
# The difference is: [727.34188034]
#
# Original value: [38995] vs the predicted value: 35079.175
# The difference is: [3915.825]
#
# Original value: [36995] vs the predicted value: 35079.175
# The difference is: [1915.825]
#
# Original value: [21995] vs the predicted value: 19267.65811965812
# The difference is: [2727.34188034]
#
# Original value: [15998] vs the predicted value: 27547.052631578947
# The difference is: [-11549.05263158]
#
# Original value: [11500] vs the predicted value: 15975.550847457627
# The difference is: [-4475.55084746]
#
# Original value: [18998] vs the predicted value: 15975.550847457627
# The difference is: [3022.44915254]
#
# Original value: [14100] vs the predicted value: 13870.026548672566
# The difference is: [229.97345133]
#
# Original value: [16390] vs the predicted value: 19267.65811965812
# The difference is: [-2877.65811966]
#
# Original value: [19990] vs the predicted value: 15975.550847457627
# The difference is: [4014.44915254]
#
# Original value: [11650] vs the predicted value: 11112.366666666667
# The difference is: [537.63333333]
#
# Original value: [18990] vs the predicted value: 15975.550847457627
# The difference is: [3014.44915254]
#
# Original value: [33490] vs the predicted value: 41080.45
# The difference is: [-7590.45]
#
# Original value: [18995] vs the predicted value: 13870.026548672566
# The difference is: [5124.97345133]
#
# Original value: [15600] vs the predicted value: 15975.550847457627
# The difference is: [-375.55084746]
#
# Original value: [11995] vs the predicted value: 11112.366666666667
# The difference is: [882.63333333]
#
# Original value: [37995] vs the predicted value: 35079.175
# The difference is: [2915.825]
#
# Original value: [16000] vs the predicted value: 15975.550847457627
# The difference is: [24.44915254]
#
# Original value: [30995] vs the predicted value: 26979.5
# The difference is: [4015.5]
#
# Original value: [49995] vs the predicted value: 51652.416666666664
# The difference is: [-1657.41666667]
#
# Original value: [25990] vs the predicted value: 28879.4375
# The difference is: [-2889.4375]
#
# Original value: [23985] vs the predicted value: 19483.176470588234
# The difference is: [4501.82352941]
#
# Original value: [17395] vs the predicted value: 15975.550847457627
# The difference is: [1419.44915254]
#
# Original value: [16498] vs the predicted value: 19267.65811965812
# The difference is: [-2769.65811966]
#
# Original value: [24365] vs the predicted value: 22574.5
# The difference is: [1790.5]
#
# Original value: [29985] vs the predicted value: 28905.85714285714
# The difference is: [1079.14285714]
#
# Original value: [14995] vs the predicted value: 19483.176470588234
# The difference is: [-4488.17647059]
#
# Original value: [22945] vs the predicted value: 15975.550847457627
# The difference is: [6969.44915254]
#
# Original value: [47995] vs the predicted value: 51652.416666666664
# The difference is: [-3657.41666667]
#
# Original value: [19995] vs the predicted value: 13870.026548672566
# The difference is: [6124.97345133]
#
# Original value: [21450] vs the predicted value: 19483.176470588234
# The difference is: [1966.82352941]
#
# Original value: [11998] vs the predicted value: 13870.026548672566
# The difference is: [-1872.02654867]
#
# Original value: [23995] vs the predicted value: 19267.65811965812
# The difference is: [4727.34188034]
#
# Original value: [10200] vs the predicted value: 13870.026548672566
# The difference is: [-3670.02654867]
#
# Original value: [30995] vs the predicted value: 26979.5
# The difference is: [4015.5]
#
# Original value: [49995] vs the predicted value: 51652.416666666664
# The difference is: [-1657.41666667]
#
# Original value: [12450] vs the predicted value: 13870.026548672566
# The difference is: [-1420.02654867]
#
# Original value: [23995] vs the predicted value: 19483.176470588234
# The difference is: [4511.82352941]
#
# Original value: [16995] vs the predicted value: 15975.550847457627
# The difference is: [1019.44915254]
#
# Original value: [34485] vs the predicted value: 30839.352941176472
# The difference is: [3645.64705882]
#
# Original value: [19995] vs the predicted value: 26979.5
# The difference is: [-6984.5]
#
# Original value: [25998] vs the predicted value: 30839.352941176472
# The difference is: [-4841.35294118]
#
# Original value: [21500] vs the predicted value: 27547.052631578947
# The difference is: [-6047.05263158]
#
# Original value: [21288] vs the predicted value: 19483.176470588234
# The difference is: [1804.82352941]
#
# Original value: [12495] vs the predicted value: 13870.026548672566
# The difference is: [-1375.02654867]
#
# Original value: [36995] vs the predicted value: 35079.175
# The difference is: [1915.825]
#
# Original value: [51995] vs the predicted value: 41080.45
# The difference is: [10914.55]
#
# Original value: [14998] vs the predicted value: 13870.026548672566
# The difference is: [1127.97345133]
#
# Original value: [20495] vs the predicted value: 19267.65811965812
# The difference is: [1227.34188034]
#
# Original value: [22995] vs the predicted value: 19483.176470588234
# The difference is: [3511.82352941]
#
# Original value: [25000] vs the predicted value: 19267.65811965812
# The difference is: [5732.34188034]
#
# Original value: [11300] vs the predicted value: 13870.026548672566
# The difference is: [-2570.02654867]
#
# Original value: [20890] vs the predicted value: 19483.176470588234
# The difference is: [1406.82352941]
#
# Original value: [20498] vs the predicted value: 19483.176470588234
# The difference is: [1014.82352941]
#
# Original value: [36497] vs the predicted value: 30839.352941176472
# The difference is: [5657.64705882]
#
# Original value: [16900] vs the predicted value: 19267.65811965812
# The difference is: [-2367.65811966]
#
# Original value: [42500] vs the predicted value: 41080.45
# The difference is: [1419.55]
#
# Original value: [33444] vs the predicted value: 35079.175
# The difference is: [-1635.175]
#
# Original value: [27022] vs the predicted value: 26979.5
# The difference is: [42.5]
#
# Original value: [14998] vs the predicted value: 15975.550847457627
# The difference is: [-977.55084746]
#
# Original value: [37507] vs the predicted value: 26979.5
# The difference is: [10527.5]
#
# Original value: [18300] vs the predicted value: 19483.176470588234
# The difference is: [-1183.17647059]
#
# Original value: [14495] vs the predicted value: 15975.550847457627
# The difference is: [-1480.55084746]
#
# Original value: [27990] vs the predicted value: 30839.352941176472
# The difference is: [-2849.35294118]
#
# Original value: [37888] vs the predicted value: 35079.175
# The difference is: [2808.825]
#
# Original value: [47995] vs the predicted value: 51652.416666666664
# The difference is: [-3657.41666667]
#
# Original value: [17100] vs the predicted value: 35079.175
# The difference is: [-17979.175]
#
# Original value: [22663] vs the predicted value: 22574.5
# The difference is: [88.5]
#
# Original value: [21498] vs the predicted value: 19267.65811965812
# The difference is: [2230.34188034]
#
# Original value: [13688] vs the predicted value: 13870.026548672566
# The difference is: [-182.02654867]
#
# Original value: [9998] vs the predicted value: 13870.026548672566
# The difference is: [-3872.02654867]
#
# Original value: [33444] vs the predicted value: 35079.175
# The difference is: [-1635.175]
#
# Original value: [41888] vs the predicted value: 38518.666666666664
# The difference is: [3369.33333333]
#
# Original value: [17200] vs the predicted value: 15975.550847457627
# The difference is: [1224.44915254]
#
# Original value: [28995] vs the predicted value: 36692.57142857143
# The difference is: [-7697.57142857]
#
# Original value: [49990] vs the predicted value: 51652.416666666664
# The difference is: [-1662.41666667]
#
# Original value: [28000] vs the predicted value: 30839.352941176472
# The difference is: [-2839.35294118]
#
# Original value: [20088] vs the predicted value: 19267.65811965812
# The difference is: [820.34188034]
#
# Original value: [20350] vs the predicted value: 22574.5
# The difference is: [-2224.5]
#
# Original value: [42995] vs the predicted value: 41080.45
# The difference is: [1914.55]
#
# Original value: [32494] vs the predicted value: 30839.352941176472
# The difference is: [1654.64705882]
#
# Original value: [16200] vs the predicted value: 19267.65811965812
# The difference is: [-3067.65811966]
#
# Original value: [11300] vs the predicted value: 11112.366666666667
# The difference is: [187.63333333]
#
# Original value: [23995] vs the predicted value: 22574.5
# The difference is: [1420.5]
#
# Original value: [11495] vs the predicted value: 11112.366666666667
# The difference is: [382.63333333]
#
# Original value: [10000] vs the predicted value: 13870.026548672566
# The difference is: [-3870.02654867]
#
# Original value: [19995] vs the predicted value: 19267.65811965812
# The difference is: [727.34188034]
#
# Original value: [18995] vs the predicted value: 13870.026548672566
# The difference is: [5124.97345133]
#
# Original value: [23995] vs the predicted value: 19483.176470588234
# The difference is: [4511.82352941]
#
# Original value: [28995] vs the predicted value: 27547.052631578947
# The difference is: [1447.94736842]
#
# Original value: [16998] vs the predicted value: 19267.65811965812
# The difference is: [-2269.65811966]
#
# Original value: [19485] vs the predicted value: 19267.65811965812
# The difference is: [217.34188034]
#
# Original value: [22698] vs the predicted value: 25478.0
# The difference is: [-2780.]
#
# Original value: [33995] vs the predicted value: 35079.175
# The difference is: [-1084.175]
#
# Original value: [21495] vs the predicted value: 19267.65811965812
# The difference is: [2227.34188034]
#
# Original value: [23995] vs the predicted value: 19267.65811965812
# The difference is: [4727.34188034]
#
# Original value: [17950] vs the predicted value: 19483.176470588234
# The difference is: [-1533.17647059]
#
# Original value: [22995] vs the predicted value: 19267.65811965812
# The difference is: [3727.34188034]
#
# Original value: [27498] vs the predicted value: 15975.550847457627
# The difference is: [11522.44915254]
#
# Original value: [19498] vs the predicted value: 15975.550847457627
# The difference is: [3522.44915254]
#
# Original value: [17695] vs the predicted value: 13870.026548672566
# The difference is: [3824.97345133]
#
# Original value: [21285] vs the predicted value: 22574.5
# The difference is: [-1289.5]
#
# Original value: [15700] vs the predicted value: 19267.65811965812
# The difference is: [-3567.65811966]
#
# Original value: [25499] vs the predicted value: 30839.352941176472
# The difference is: [-5340.35294118]
#
# Original value: [17998] vs the predicted value: 13870.026548672566
# The difference is: [4127.97345133]
#
# Original value: [17998] vs the predicted value: 19267.65811965812
# The difference is: [-1269.65811966]
#
# Original value: [16498] vs the predicted value: 19267.65811965812
# The difference is: [-2769.65811966]
#
# Original value: [13995] vs the predicted value: 13870.026548672566
# The difference is: [124.97345133]
#
# Original value: [60995] vs the predicted value: 51652.416666666664
# The difference is: [9342.58333333]
#
# Original value: [17500] vs the predicted value: 15975.550847457627
# The difference is: [1524.44915254]
#
# Original value: [15998] vs the predicted value: 35079.175
# The difference is: [-19081.175]
#
# Original value: [29000] vs the predicted value: 26979.5
# The difference is: [2020.5]
#
# Original value: [25000] vs the predicted value: 28879.4375
# The difference is: [-3879.4375]
#
# Original value: [31998] vs the predicted value: 35079.175
# The difference is: [-3081.175]
#
# Original value: [16100] vs the predicted value: 13870.026548672566
# The difference is: [2229.97345133]
#
# Original value: [39454] vs the predicted value: 30839.352941176472
# The difference is: [8614.64705882]
#
# Original value: [17298] vs the predicted value: 19267.65811965812
# The difference is: [-1969.65811966]
#
# Original value: [25995] vs the predicted value: 19267.65811965812
# The difference is: [6727.34188034]
#
# Original value: [16100] vs the predicted value: 19267.65811965812
# The difference is: [-3167.65811966]
#
# Original value: [21995] vs the predicted value: 19267.65811965812
# The difference is: [2727.34188034]
#
# Original value: [15200] vs the predicted value: 15975.550847457627
# The difference is: [-775.55084746]
#
# Original value: [14500] vs the predicted value: 15975.550847457627
# The difference is: [-1475.55084746]
#
# Original value: [28985] vs the predicted value: 28879.4375
# The difference is: [105.5625]
#
# Original value: [17998] vs the predicted value: 19267.65811965812
# The difference is: [-1269.65811966]
#
# Original value: [15000] vs the predicted value: 19267.65811965812
# The difference is: [-4267.65811966]
#
# Original value: [19500] vs the predicted value: 18343.75
# The difference is: [1156.25]
#
# Original value: [34995] vs the predicted value: 30839.352941176472
# The difference is: [4155.64705882]
#
# Original value: [26495] vs the predicted value: 30839.352941176472
# The difference is: [-4344.35294118]
#
# Original value: [34259] vs the predicted value: 28879.4375
# The difference is: [5379.5625]
#
# Original value: [16995] vs the predicted value: 15975.550847457627
# The difference is: [1019.44915254]
#
# Original value: [25995] vs the predicted value: 28879.4375
# The difference is: [-2884.4375]
#
# Original value: [20000] vs the predicted value: 15975.550847457627
# The difference is: [4024.44915254]
#
# Original value: [20200] vs the predicted value: 19267.65811965812
# The difference is: [932.34188034]
#
# Original value: [16998] vs the predicted value: 15975.550847457627
# The difference is: [1022.44915254]
#
# Original value: [12698] vs the predicted value: 15975.550847457627
# The difference is: [-3277.55084746]
#
# Original value: [15995] vs the predicted value: 15975.550847457627
# The difference is: [19.44915254]
#
# Original value: [12798] vs the predicted value: 13870.026548672566
# The difference is: [-1072.02654867]
#
# Original value: [26990] vs the predicted value: 26979.5
# The difference is: [10.5]
#
# Original value: [18990] vs the predicted value: 15975.550847457627
# The difference is: [3014.44915254]
#
# Original value: [22988] vs the predicted value: 19267.65811965812
# The difference is: [3720.34188034]
#
# Original value: [18990] vs the predicted value: 18343.75
# The difference is: [646.25]
#
# Original value: [13998] vs the predicted value: 15975.550847457627
# The difference is: [-1977.55084746]
#
# Original value: [35131] vs the predicted value: 28879.4375
# The difference is: [6251.5625]
#
# Original value: [22490] vs the predicted value: 28879.4375
# The difference is: [-6389.4375]
#
# Original value: [35895] vs the predicted value: 30839.352941176472
# The difference is: [5055.64705882]
#
# Original value: [33298] vs the predicted value: 30839.352941176472
# The difference is: [2458.64705882]
#
# Original value: [35995] vs the predicted value: 35079.175
# The difference is: [915.825]
#
# Original value: [16000] vs the predicted value: 13870.026548672566
# The difference is: [2129.97345133]
#
# Original value: [36995] vs the predicted value: 30839.352941176472
# The difference is: [6155.64705882]
#
# Original value: [36998] vs the predicted value: 41080.45
# The difference is: [-4082.45]
#
# Original value: [25990] vs the predicted value: 28879.4375
# The difference is: [-2889.4375]
#
# Original value: [30543] vs the predicted value: 35079.175
# The difference is: [-4536.175]
#
# Original value: [24995] vs the predicted value: 19267.65811965812
# The difference is: [5727.34188034]
#
# Original value: [15000] vs the predicted value: 15975.550847457627
# The difference is: [-975.55084746]
#
# Original value: [14300] vs the predicted value: 15975.550847457627
# The difference is: [-1675.55084746]
#
# Original value: [13498] vs the predicted value: 13870.026548672566
# The difference is: [-372.02654867]
#
# Original value: [30995] vs the predicted value: 30839.352941176472
# The difference is: [155.64705882]
#
# Original value: [19995] vs the predicted value: 19483.176470588234
# The difference is: [511.82352941]
#
# Original value: [19995] vs the predicted value: 19267.65811965812
# The difference is: [727.34188034]
#
# Original value: [35998] vs the predicted value: 35079.175
# The difference is: [918.825]
#
# Original value: [21490] vs the predicted value: 22574.5
# The difference is: [-1084.5]
#
# Original value: [25995] vs the predicted value: 13870.026548672566
# The difference is: [12124.97345133]
#
# Original value: [11600] vs the predicted value: 13870.026548672566
# The difference is: [-2270.02654867]
#
# Original value: [18950] vs the predicted value: 19267.65811965812
# The difference is: [-317.65811966]
#
# Original value: [19495] vs the predicted value: 15975.550847457627
# The difference is: [3519.44915254]
#
# Original value: [59995] vs the predicted value: 44843.125
# The difference is: [15151.875]
#
# Original value: [9998] vs the predicted value: 13870.026548672566
# The difference is: [-3872.02654867]
#
# Original value: [15600] vs the predicted value: 19483.176470588234
# The difference is: [-3883.17647059]
#
# Original value: [19995] vs the predicted value: 19483.176470588234
# The difference is: [511.82352941]
#
# Original value: [31000] vs the predicted value: 35079.175
# The difference is: [-4079.175]
#
# Original value: [19800] vs the predicted value: 26979.5
# The difference is: [-7179.5]
#
# Original value: [16000] vs the predicted value: 15975.550847457627
# The difference is: [24.44915254]
#
# Original value: [59995] vs the predicted value: 51652.416666666664
# The difference is: [8342.58333333]
#
# Original value: [36990] vs the predicted value: 13870.026548672566
# The difference is: [23119.97345133]
#
# Original value: [27985] vs the predicted value: 28879.4375
# The difference is: [-894.4375]
#
# Original value: [52995] vs the predicted value: 51652.416666666664
# The difference is: [1342.58333333]
#
# Original value: [22285] vs the predicted value: 19483.176470588234
# The difference is: [2801.82352941]
#
# Original value: [30995] vs the predicted value: 27547.052631578947
# The difference is: [3447.94736842]
#
# Original value: [14500] vs the predicted value: 13870.026548672566
# The difference is: [629.97345133]
#
# Original value: [52995] vs the predicted value: 38518.666666666664
# The difference is: [14476.33333333]
#
# Original value: [10995] vs the predicted value: 11112.366666666667
# The difference is: [-117.36666667]
#
# Original value: [52995] vs the predicted value: 44843.125
# The difference is: [8151.875]
#
# Original value: [23995] vs the predicted value: 22574.5
# The difference is: [1420.5]
#
# Original value: [17200] vs the predicted value: 30839.352941176472
# The difference is: [-13639.35294118]
#
# Original value: [15998] vs the predicted value: 19267.65811965812
# The difference is: [-3269.65811966]
#
# Original value: [19495] vs the predicted value: 22574.5
# The difference is: [-3079.5]
#
# Original value: [24985] vs the predicted value: 26979.5
# The difference is: [-1994.5]
#
# Original value: [16400] vs the predicted value: 13870.026548672566
# The difference is: [2529.97345133]

# %% [markdown]
# # User Input Predictions

# %%
inputPred = []
entries = []

def userInput():
    chooseBrand = input("Choose your car brand: Audi, BMW, Ford, Hyundai, Mercedes, Skoda, Toyota, Vauxhall or Volkswagen \n")
    
    if chooseBrand == "Audi":
        return "UKUsedCarDataSet/audi.csv"
    elif chooseBrand == "BMW":
        return "UKUsedCarDataSet/bmw.csv"
    elif chooseBrand == "Ford":
        return "UKUsedCarDataSet/ford.csv"
    elif chooseBrand == "Hyundai":
        return "UKUsedCarDataSet/hyundi.csv"
    elif chooseBrand == "Mercedes":
        return "UKUsedCarDataSet/merc.csv"
    elif chooseBrand == "Skoda":
        return "UKUsedCarDataSet/skoda.csv"
    elif chooseBrand == "Toyota":
        return "UKUsedCarDataSet/toyota.csv"
    elif chooseBrand == "Vauxhall":
        return "UKUsedCarDataSet/vauxhall.csv"
    elif chooseBrand == "Volkswagen":
        return "UKUsedCarDataSet/vw.csv"
    else:
        print("Invalid Car Brand")
        userInput()
    return 

X_train, X_test, Y_train, Y_test = dataset(userInput())
print("\n ***Training Tree Model***")
myTree = DTRegressor(3, 93)  
myTree.fit(X_train, Y_train)

print("\n List of models:")
print(list(modelEncoder.classes_))
inputPred.append((modelEncoder.transform([input("\nWhat Model is your car? ")]))[0])
inputPred.append(int(input("What year is your car? ")))
inputPred.append((transmissionEncoder.transform([input("What transmission is your car? ")]))[0])
inputPred.append(int(input("How much mileage does your car have? ")))
inputPred.append((fuelTypeEncoder.transform([input("What's your car fuel type? ")]))[0])
inputPred.append(int(input("How much is your cars tax? ")))
inputPred.append(float(input("What's MPG of your car? ")))
inputPred.append(float(input("What the engine size of your car? ")))
entries.append(inputPred)
# inputPred = scaler.transform([inputPred])

import time
print("\n ***Predicting***")
start = time.time()
y_pred = myTree.predict([inputPred])
# {0:.2f}'.format()
print("\n Predicted price for your car is: £", y_pred[0])

print("\n ***Predicted in", time.time() - start,"seconds***")

# RS6,2016,Semi-Auto,49050,Petrol,325,29.4,4.0 -- Price is £44,985   old Pred = £41,233.30,  new pred = £45492.50
# BMW,5 Series,2019,Semi-Auto,4405,Petrol,145,48.7,2.0     Price = £26,000 old Pred = £27,077.49, new pred = £26500.00
# Out:
# Choose your car brand: Audi, BMW, Ford, Hyundai, Mercedes, Skoda, Toyota, Vauxhall or Volkswagen
# Audi
#
#  ***Training Tree Model***
#
#  List of models:
# ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'Q2', 'Q3', 'Q5', 'Q7', 'Q8', 'R8', 'RS3', 'RS4', 'RS5', 'RS6', 'RS7', 'S3', 'S4', 'S5', 'S8', 'SQ5', 'SQ7', 'TT']
#
# What Model is your car? RS6
# What year is your car? 2016
# What transmission is your car? Semi-Auto
# How much mileage does your car have? 49050
# What's your car fuel type? Petrol
# How much is your cars tax? 325
# What's MPG of your car? 29.4
# What the engine size of your car? 4
#
#  ***Predicting***
#
#  Predicted price for your car is: £ 45492.5
#
#  ***Predicted in 0.0007822513580322266 seconds***
