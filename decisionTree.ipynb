# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import csv
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
from sklearn.metrics import mean_squared_error 
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.tree import plot_tree

# %% [markdown]
# # Importing and Splitting data

# %%
modelEncoder = LabelEncoder()
transmissionEncoder = LabelEncoder()
fuelTypeEncoder = LabelEncoder()

def dataset(brand):

    file = pd.read_csv(brand, quotechar='"', skipinitialspace=True)

    modelEncoder.fit(file["model"])
    file["model"] = modelEncoder.transform(file["model"])

    transmissionEncoder.fit(file["transmission"])
    file["transmission"] = transmissionEncoder.transform(file["transmission"])

    fuelTypeEncoder.fit(file["fuelType"])
    file["fuelType"] = fuelTypeEncoder.transform(file["fuelType"])

    file = file.head(5000)
    # X = file.drop(columns = ['price'])
    # Y = file.price
    # print(file)

    X = file.drop(['price'], axis = 1).to_numpy()
    # X = file[['year', 'mileage', 'tax', 'mpg', 'engineSize']].to_numpy(dtype = 'int')
    Y = file['price'].values.reshape(-1,1)

#     print(X)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 601)
    
    return  X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = dataset("UKUsedCarDataSet/audi.csv") # Use Audi dataset as default for KNN analysis

# %% [markdown]
# # Using Scikit-Learn

# %%
myTree = DecisionTreeRegressor(random_state = 601, max_depth = 34, min_samples_split = 3) #, max_depth = 3
myTree.fit(X_train, Y_train)
print("R Squared: ", myTree.score(X_test, Y_test))
#92, 3 = 0.8593705968859954
#5, 3 = 0.7566846373060692
#34, 3 = 0.8593705968859954
# Out:
# R Squared:  0.8593705968859954

# %% [markdown]
# # GridSeacrhCV to find optimal parameters

# %%
from sklearn.model_selection import GridSearchCV

# params = {'min_samples_split': [2, 3, 4], 'max_leaf_nodes': list(range(2, 100)), 'max_depth': list(range(1, 100))} #'max_leaf_nodes': list(range(2, 100)),
# params = {'min_samples_split': [3, 4, 5, 6], 'max_depth': list(range(1, 6)), 'max_leaf_nodes': list(range(2, 6))}
params = {'min_samples_split': list(range(2, 100)), 'max_leaf_nodes': list(range(2, 100)), 'max_depth': list(range(2, 100))}
grid_search_cv = GridSearchCV(myTree, params, cv=3)
grid_search_cv.fit(X_train, Y_train)

# %%
grid_search_cv.best_estimator_

# %% [markdown]
# # Visualising Decsion Tree:

# %% [markdown]
# X1 = file.drop(['price'], axis = 1)
#
# plt.figure(figsize=(20, 10), dpi = 200)
# plot_tree(myTree, feature_names = X1.columns, filled=True);

# %% [markdown]
# # RMSE

# %%
def rmse(h, y):
  return sqrt(mean_squared_error(h, y))

# %% [markdown]
# # Node Class

# %%
# Node class to initialise instances of each 
class Node():
    
    def __init__(self, feature = None, limit = None, leftSide = None, rightSide = None, gain = None, leaf = None):
        
        self.feature = feature
        self.limit = limit
        self.leftSide = leftSide
        self.rightSide = rightSide
        self.gain = gain
        self.leaf = leaf

# %% [markdown]
# # Decision Tree Regression Class

# %%
class DTRegressor():
    def __init__(self, minSamples, maxDepth):
        self.root = None
        self.minSamples = minSamples
        self.maxDepth = maxDepth
        
    def infoGain(self, parent, leftNode, rightNode):
        leftWeight = len(leftNode) / len(parent)
        rightWeight = len(rightNode) / len(parent)
        
        informationGain = np.var(parent) - (leftWeight * np.var(leftNode) + rightWeight * np.var(rightNode))

        return informationGain
        
    def splitTree(self, trainingSet, feature, limit):
        leftBranch = []
        rightBranch = []
        for i in trainingSet:
            if i[feature] <= limit:
                leftBranch.append(i)
            else:
                rightBranch.append(i)
        rightBranch = np.array(rightBranch)
        leftBranch = np.array(leftBranch)
        return leftBranch, rightBranch
        
    def bestSplit(self, trainingSet, X):
        bestSplitt = {} 
        biggestGain = -1
        for feature in range(X.shape[1]): 
#             featureValues = trainingSet[:, feature] #current feature selected
            featureValues = []
            for i in range(len(trainingSet)):
                featureValues.append(trainingSet[i, feature])
            thresholds = np.unique(featureValues)
            for j in thresholds: #j = threshold
                leftSide, rightSide = self.splitTree(trainingSet, feature, j) #splits node into 2 sub-trees
                if (len(leftSide) > 0 and len(rightSide) > 0 ):
                    parent = []
                    for i in range(len(trainingSet)):
                        parent.append(trainingSet[i, -1])

                    leftNode = []
                    for i in range(len(leftSide)):
                        leftNode.append(leftSide[i, -1])
                        
                    rightNode = []
                    for i in range(len(rightSide)):
                        rightNode.append(rightSide[i, -1])

                    currentGain = self.infoGain(parent, leftNode, rightNode) 
                    if currentGain > biggestGain:
                        
                        bestSplitt["feature"] = feature
                        bestSplitt["limit"] = j
                        bestSplitt["leftSide"] = leftSide
                        bestSplitt["rightSide"] = rightSide
                        bestSplitt["gain"] = currentGain
                        biggestGain = currentGain
                
        return bestSplitt
   
        
    def treeBuild(self, trainingSet, currentDepth = 0):
        
#       #Split training into features and labels
        X = trainingSet[:,:-1] # everything but the last value
        Y = []
        for i in range(len(trainingSet)):
            Y.append(trainingSet[i, -1])# only the last value
        
        #iterates until this condition is met
        if X.shape[0] >= self.minSamples and currentDepth <= self.maxDepth:
#             bestSplit = self.bestSplit(trainingSet, samplesNumb, featuresNumb)
            bestSplitNode = self.bestSplit(trainingSet, X)
            
            if "gain" in bestSplitNode and bestSplitNode["gain"] > 0:
                leftTree = self.treeBuild(bestSplitNode["leftSide"], currentDepth + 1)
                rightTree = self.treeBuild(bestSplitNode["rightSide"], currentDepth + 1)
                node = Node(bestSplitNode["feature"], bestSplitNode["limit"], leftTree, rightTree, bestSplitNode["gain"])

                return node
        
        leafValue = np.mean(Y) #calculates mean of leaf nodes
        val = Node(leaf = leafValue)
        return val
    
    def predictionLoop(self, testRow, root):
        if root.leaf != None: #not empty
            return root.leaf
        
        featureVal = testRow[root.feature]
        if featureVal <= root.limit:
            return self.predictionLoop(testRow, root.leftSide)
        else:
            return self.predictionLoop(testRow, root.rightSide)
        
   
    def predict(self, xTest):
        predictions = []
        for row in xTest:
            predictions.append(self.predictionLoop(row, self.root)) 
        return predictions

        
        
    def fit(self, X, Y):
#         print(Y)
        trainingSet = np.concatenate((X, Y), axis=1) #Joins training data back together
        self.root = self.treeBuild(trainingSet)

# %% [markdown]
# # Training the algorithm

# %%
myTree = DTRegressor(3, 34) #then 34, 3
myTree.fit(X_train, Y_train) #trains the model using the training set
#3, 11 = 4331.929325238453
#3, 34 = 4355.8298808608215

# %% [markdown]
# # Evaluation

# %%
def evaluation(train, test, yTrain, yTest):    
    y_pred = myTree.predict(X_test)
    # print(y_pred)
    error = rmse(yTest, y_pred) 
    print('The RMSE value is:', error)
    for i in range(len(y_pred)):
        print("\nOriginal value:", yTest[i], "vs the predicted value:", y_pred[i])
        print("The difference is:", yTest[i] - y_pred[i])
evaluation(X_train, X_test, Y_train, Y_test)
# Old RMSE value was 5486.187742617547
#4355.8298808608215 = 3, 34
#4331.929325238453 = 3, 11
#5050.108048448073 with entropy method
#3027.4338424903326 with 5000 values
# Out:
# The RMSE value is: 3027.4338424903326
#
# Original value: [17498] vs the predicted value: 15498.0
# The difference is: [2000.]
#
# Original value: [25990] vs the predicted value: 25495.0
# The difference is: [495.]
#
# Original value: [26495] vs the predicted value: 20391.0
# The difference is: [6104.]
#
# Original value: [14791] vs the predicted value: 17490.0
# The difference is: [-2699.]
#
# Original value: [26888] vs the predicted value: 26888.0
# The difference is: [0.]
#
# Original value: [29500] vs the predicted value: 28997.5
# The difference is: [502.5]
#
# Original value: [12498] vs the predicted value: 11995.0
# The difference is: [503.]
#
# Original value: [11980] vs the predicted value: 10550.0
# The difference is: [1430.]
#
# Original value: [12898] vs the predicted value: 12998.0
# The difference is: [-100.]
#
# Original value: [20452] vs the predicted value: 15783.5
# The difference is: [4668.5]
#
# Original value: [15991] vs the predicted value: 16742.5
# The difference is: [-751.5]
#
# Original value: [12750] vs the predicted value: 13300.0
# The difference is: [-550.]
#
# Original value: [17998] vs the predicted value: 16995.0
# The difference is: [1003.]
#
# Original value: [20495] vs the predicted value: 20650.0
# The difference is: [-155.]
#
# Original value: [14470] vs the predicted value: 14692.5
# The difference is: [-222.5]
#
# Original value: [36990] vs the predicted value: 35495.0
# The difference is: [1495.]
#
# Original value: [38888] vs the predicted value: 42745.5
# The difference is: [-3857.5]
#
# Original value: [15498] vs the predicted value: 14119.0
# The difference is: [1379.]
#
# Original value: [34798] vs the predicted value: 32481.0
# The difference is: [2317.]
#
# Original value: [28991] vs the predicted value: 36312.0
# The difference is: [-7321.]
#
# Original value: [30000] vs the predicted value: 29372.5
# The difference is: [627.5]
#
# Original value: [23690] vs the predicted value: 24477.0
# The difference is: [-787.]
#
# Original value: [12891] vs the predicted value: 14400.0
# The difference is: [-1509.]
#
# Original value: [23912] vs the predicted value: 33995.0
# The difference is: [-10083.]
#
# Original value: [18440] vs the predicted value: 18248.0
# The difference is: [192.]
#
# Original value: [17200] vs the predicted value: 24698.0
# The difference is: [-7498.]
#
# Original value: [28371] vs the predicted value: 26903.5
# The difference is: [1467.5]
#
# Original value: [24212] vs the predicted value: 21288.0
# The difference is: [2924.]
#
# Original value: [12998] vs the predicted value: 11344.0
# The difference is: [1654.]
#
# Original value: [19000] vs the predicted value: 21624.0
# The difference is: [-2624.]
#
# Original value: [28990] vs the predicted value: 28691.0
# The difference is: [299.]
#
# Original value: [23995] vs the predicted value: 29490.0
# The difference is: [-5495.]
#
# Original value: [27888] vs the predicted value: 25491.0
# The difference is: [2397.]
#
# Original value: [45000] vs the predicted value: 45990.0
# The difference is: [-990.]
#
# Original value: [31998] vs the predicted value: 31248.0
# The difference is: [750.]
#
# Original value: [12500] vs the predicted value: 11070.0
# The difference is: [1430.]
#
# Original value: [24500] vs the predicted value: 23245.5
# The difference is: [1254.5]
#
# Original value: [9995] vs the predicted value: 13498.0
# The difference is: [-3503.]
#
# Original value: [15990] vs the predicted value: 12495.0
# The difference is: [3495.]
#
# Original value: [23500] vs the predicted value: 26939.0
# The difference is: [-3439.]
#
# Original value: [18896] vs the predicted value: 17020.5
# The difference is: [1875.5]
#
# Original value: [22995] vs the predicted value: 24291.0
# The difference is: [-1296.]
#
# Original value: [12798] vs the predicted value: 16240.0
# The difference is: [-3442.]
#
# Original value: [22495] vs the predicted value: 22934.5
# The difference is: [-439.5]
#
# Original value: [19995] vs the predicted value: 18995.0
# The difference is: [1000.]
#
# Original value: [23290] vs the predicted value: 24990.0
# The difference is: [-1700.]
#
# Original value: [18781] vs the predicted value: 19495.0
# The difference is: [-714.]
#
# Original value: [23495] vs the predicted value: 21749.0
# The difference is: [1746.]
#
# Original value: [11995] vs the predicted value: 12146.5
# The difference is: [-151.5]
#
# Original value: [13990] vs the predicted value: 12112.5
# The difference is: [1877.5]
#
# Original value: [13852] vs the predicted value: 12995.0
# The difference is: [857.]
#
# Original value: [30000] vs the predicted value: 29372.5
# The difference is: [627.5]
#
# Original value: [21495] vs the predicted value: 22969.5
# The difference is: [-1474.5]
#
# Original value: [23166] vs the predicted value: 21992.0
# The difference is: [1174.]
#
# Original value: [17250] vs the predicted value: 17998.0
# The difference is: [-748.]
#
# Original value: [11998] vs the predicted value: 10167.5
# The difference is: [1830.5]
#
# Original value: [60000] vs the predicted value: 65490.0
# The difference is: [-5490.]
#
# Original value: [30500] vs the predicted value: 28490.0
# The difference is: [2010.]
#
# Original value: [8895] vs the predicted value: 10998.0
# The difference is: [-2103.]
#
# Original value: [18120] vs the predicted value: 15495.0
# The difference is: [2625.]
#
# Original value: [22500] vs the predicted value: 19939.0
# The difference is: [2561.]
#
# Original value: [13298] vs the predicted value: 14344.5
# The difference is: [-1046.5]
#
# Original value: [11995] vs the predicted value: 11600.0
# The difference is: [395.]
#
# Original value: [10500] vs the predicted value: 10131.0
# The difference is: [369.]
#
# Original value: [34995] vs the predicted value: 36420.0
# The difference is: [-1425.]
#
# Original value: [18695] vs the predicted value: 21139.5
# The difference is: [-2444.5]
#
# Original value: [16596] vs the predicted value: 16350.0
# The difference is: [246.]
#
# Original value: [29975] vs the predicted value: 31000.0
# The difference is: [-1025.]
#
# Original value: [29991] vs the predicted value: 31745.5
# The difference is: [-1754.5]
#
# Original value: [20495] vs the predicted value: 18849.0
# The difference is: [1646.]
#
# Original value: [14991] vs the predicted value: 13345.0
# The difference is: [1646.]
#
# Original value: [12291] vs the predicted value: 12972.5
# The difference is: [-681.5]
#
# Original value: [32000] vs the predicted value: 30495.0
# The difference is: [1505.]
#
# Original value: [16000] vs the predicted value: 16436.0
# The difference is: [-436.]
#
# Original value: [29562] vs the predicted value: 30936.5
# The difference is: [-1374.5]
#
# Original value: [16800] vs the predicted value: 14450.0
# The difference is: [2350.]
#
# Original value: [9995] vs the predicted value: 11491.0
# The difference is: [-1496.]
#
# Original value: [47850] vs the predicted value: 51990.0
# The difference is: [-4140.]
#
# Original value: [34990] vs the predicted value: 29995.0
# The difference is: [4995.]
#
# Original value: [33990] vs the predicted value: 28766.0
# The difference is: [5224.]
#
# Original value: [18990] vs the predicted value: 17720.0
# The difference is: [1270.]
#
# Original value: [39881] vs the predicted value: 38995.0
# The difference is: [886.]
#
# Original value: [17520] vs the predicted value: 18495.0
# The difference is: [-975.]
#
# Original value: [15500] vs the predicted value: 19498.0
# The difference is: [-3998.]
#
# Original value: [17895] vs the predicted value: 20498.0
# The difference is: [-2603.]
#
# Original value: [44990] vs the predicted value: 46000.0
# The difference is: [-1010.]
#
# Original value: [14991] vs the predicted value: 12998.0
# The difference is: [1993.]
#
# Original value: [16200] vs the predicted value: 18696.0
# The difference is: [-2496.]
#
# Original value: [13995] vs the predicted value: 12217.0
# The difference is: [1778.]
#
# Original value: [9695] vs the predicted value: 9990.0
# The difference is: [-295.]
#
# Original value: [26676] vs the predicted value: 22943.0
# The difference is: [3733.]
#
# Original value: [14481] vs the predicted value: 14242.5
# The difference is: [238.5]
#
# Original value: [37500] vs the predicted value: 29786.0
# The difference is: [7714.]
#
# Original value: [27000] vs the predicted value: 24260.0
# The difference is: [2740.]
#
# Original value: [16342] vs the predicted value: 16996.5
# The difference is: [-654.5]
#
# Original value: [34000] vs the predicted value: 33491.0
# The difference is: [509.]
#
# Original value: [13490] vs the predicted value: 10167.5
# The difference is: [3322.5]
#
# Original value: [17495] vs the predicted value: 15775.0
# The difference is: [1720.]
#
# Original value: [37999] vs the predicted value: 38147.0
# The difference is: [-148.]
#
# Original value: [18781] vs the predicted value: 17790.0
# The difference is: [991.]
#
# Original value: [16000] vs the predicted value: 16550.0
# The difference is: [-550.]
#
# Original value: [23995] vs the predicted value: 23995.0
# The difference is: [0.]
#
# Original value: [18505] vs the predicted value: 18994.0
# The difference is: [-489.]
#
# Original value: [35990] vs the predicted value: 31439.0
# The difference is: [4551.]
#
# Original value: [24896] vs the predicted value: 19499.0
# The difference is: [5397.]
#
# Original value: [21946] vs the predicted value: 22245.0
# The difference is: [-299.]
#
# Original value: [56990] vs the predicted value: 53490.0
# The difference is: [3500.]
#
# Original value: [16998] vs the predicted value: 16188.5
# The difference is: [809.5]
#
# Original value: [11698] vs the predicted value: 12622.5
# The difference is: [-924.5]
#
# Original value: [17990] vs the predicted value: 18450.0
# The difference is: [-460.]
#
# Original value: [16991] vs the predicted value: 15594.0
# The difference is: [1397.]
#
# Original value: [28995] vs the predicted value: 23245.5
# The difference is: [5749.5]
#
# Original value: [24990] vs the predicted value: 20985.0
# The difference is: [4005.]
#
# Original value: [14510] vs the predicted value: 15594.0
# The difference is: [-1084.]
#
# Original value: [62000] vs the predicted value: 65490.0
# The difference is: [-3490.]
#
# Original value: [44990] vs the predicted value: 55823.333333333336
# The difference is: [-10833.33333333]
#
# Original value: [18450] vs the predicted value: 18747.5
# The difference is: [-297.5]
#
# Original value: [9390] vs the predicted value: 8698.5
# The difference is: [691.5]
#
# Original value: [16298] vs the predicted value: 17998.5
# The difference is: [-1700.5]
#
# Original value: [56990] vs the predicted value: 54740.0
# The difference is: [2250.]
#
# Original value: [35995] vs the predicted value: 35495.5
# The difference is: [499.5]
#
# Original value: [27995] vs the predicted value: 29990.0
# The difference is: [-1995.]
#
# Original value: [14995] vs the predicted value: 12995.0
# The difference is: [2000.]
#
# Original value: [12210] vs the predicted value: 10950.0
# The difference is: [1260.]
#
# Original value: [25990] vs the predicted value: 27245.0
# The difference is: [-1255.]
#
# Original value: [11990] vs the predicted value: 13234.5
# The difference is: [-1244.5]
#
# Original value: [30995] vs the predicted value: 32997.5
# The difference is: [-2002.5]
#
# Original value: [16998] vs the predicted value: 18496.5
# The difference is: [-1498.5]
#
# Original value: [9198] vs the predicted value: 9995.0
# The difference is: [-797.]
#
# Original value: [31991] vs the predicted value: 24493.0
# The difference is: [7498.]
#
# Original value: [17250] vs the predicted value: 18142.5
# The difference is: [-892.5]
#
# Original value: [18450] vs the predicted value: 18237.0
# The difference is: [213.]
#
# Original value: [13995] vs the predicted value: 14995.0
# The difference is: [-1000.]
#
# Original value: [13900] vs the predicted value: 14495.0
# The difference is: [-595.]
#
# Original value: [26990] vs the predicted value: 27745.0
# The difference is: [-755.]
#
# Original value: [16430] vs the predicted value: 17967.5
# The difference is: [-1537.5]
#
# Original value: [23000] vs the predicted value: 29490.0
# The difference is: [-6490.]
#
# Original value: [14995] vs the predicted value: 18995.0
# The difference is: [-4000.]
#
# Original value: [15698] vs the predicted value: 14145.0
# The difference is: [1553.]
#
# Original value: [31990] vs the predicted value: 30981.0
# The difference is: [1009.]
#
# Original value: [21800] vs the predicted value: 23497.0
# The difference is: [-1697.]
#
# Original value: [26995] vs the predicted value: 26242.5
# The difference is: [752.5]
#
# Original value: [16200] vs the predicted value: 13224.0
# The difference is: [2976.]
#
# Original value: [46000] vs the predicted value: 38995.0
# The difference is: [7005.]
#
# Original value: [16000] vs the predicted value: 17420.0
# The difference is: [-1420.]
#
# Original value: [37980] vs the predicted value: 35323.333333333336
# The difference is: [2656.66666667]
#
# Original value: [20250] vs the predicted value: 19992.5
# The difference is: [257.5]
#
# Original value: [18995] vs the predicted value: 19995.0
# The difference is: [-1000.]
#
# Original value: [16498] vs the predicted value: 20135.5
# The difference is: [-3637.5]
#
# Original value: [28995] vs the predicted value: 26992.5
# The difference is: [2002.5]
#
# Original value: [11990] vs the predicted value: 13747.5
# The difference is: [-1757.5]
#
# Original value: [22750] vs the predicted value: 21695.0
# The difference is: [1055.]
#
# Original value: [15998] vs the predicted value: 17490.0
# The difference is: [-1492.]
#
# Original value: [23995] vs the predicted value: 21981.0
# The difference is: [2014.]
#
# Original value: [17990] vs the predicted value: 15775.0
# The difference is: [2215.]
#
# Original value: [9690] vs the predicted value: 13234.5
# The difference is: [-3544.5]
#
# Original value: [19998] vs the predicted value: 15498.0
# The difference is: [4500.]
#
# Original value: [11498] vs the predicted value: 11794.0
# The difference is: [-296.]
#
# Original value: [27990] vs the predicted value: 26296.0
# The difference is: [1694.]
#
# Original value: [46000] vs the predicted value: 47816.0
# The difference is: [-1816.]
#
# Original value: [22500] vs the predicted value: 19993.0
# The difference is: [2507.]
#
# Original value: [19500] vs the predicted value: 20166.0
# The difference is: [-666.]
#
# Original value: [13532] vs the predicted value: 19620.5
# The difference is: [-6088.5]
#
# Original value: [11490] vs the predicted value: 13991.0
# The difference is: [-2501.]
#
# Original value: [22950] vs the predicted value: 19990.0
# The difference is: [2960.]
#
# Original value: [15860] vs the predicted value: 15975.0
# The difference is: [-115.]
#
# Original value: [21691] vs the predicted value: 22707.5
# The difference is: [-1016.5]
#
# Original value: [28000] vs the predicted value: 24792.5
# The difference is: [3207.5]
#
# Original value: [20485] vs the predicted value: 19498.0
# The difference is: [987.]
#
# Original value: [38444] vs the predicted value: 34444.0
# The difference is: [4000.]
#
# Original value: [20171] vs the predicted value: 20498.0
# The difference is: [-327.]
#
# Original value: [9800] vs the predicted value: 12111.0
# The difference is: [-2311.]
#
# Original value: [24495] vs the predicted value: 21583.333333333332
# The difference is: [2911.66666667]
#
# Original value: [17298] vs the predicted value: 16998.0
# The difference is: [300.]
#
# Original value: [10972] vs the predicted value: 11990.5
# The difference is: [-1018.5]
#
# Original value: [12500] vs the predicted value: 12645.0
# The difference is: [-145.]
#
# Original value: [19990] vs the predicted value: 18647.0
# The difference is: [1343.]
#
# Original value: [24990] vs the predicted value: 28000.0
# The difference is: [-3010.]
#
# Original value: [33995] vs the predicted value: 30899.0
# The difference is: [3096.]
#
# Original value: [12898] vs the predicted value: 12750.0
# The difference is: [148.]
#
# Original value: [17499] vs the predicted value: 19245.0
# The difference is: [-1746.]
#
# Original value: [12798] vs the predicted value: 12876.5
# The difference is: [-78.5]
#
# Original value: [29000] vs the predicted value: 26995.0
# The difference is: [2005.]
#
# Original value: [24980] vs the predicted value: 23494.0
# The difference is: [1486.]
#
# Original value: [18990] vs the predicted value: 19512.0
# The difference is: [-522.]
#
# Original value: [12498] vs the predicted value: 12040.0
# The difference is: [458.]
#
# Original value: [28985] vs the predicted value: 31985.0
# The difference is: [-3000.]
#
# Original value: [17990] vs the predicted value: 17494.0
# The difference is: [496.]
#
# Original value: [6998] vs the predicted value: 8000.0
# The difference is: [-1002.]
#
# Original value: [27200] vs the predicted value: 30997.5
# The difference is: [-3797.5]
#
# Original value: [25995] vs the predicted value: 24745.0
# The difference is: [1250.]
#
# Original value: [27444] vs the predicted value: 25491.0
# The difference is: [1953.]
#
# Original value: [17200] vs the predicted value: 17499.0
# The difference is: [-299.]
#
# Original value: [17782] vs the predicted value: 19946.5
# The difference is: [-2164.5]
#
# Original value: [15307] vs the predicted value: 18500.0
# The difference is: [-3193.]
#
# Original value: [18298] vs the predicted value: 16990.0
# The difference is: [1308.]
#
# Original value: [21226] vs the predicted value: 21495.0
# The difference is: [-269.]
#
# Original value: [16295] vs the predicted value: 16994.0
# The difference is: [-699.]
#
# Original value: [19390] vs the predicted value: 19447.5
# The difference is: [-57.5]
#
# Original value: [13998] vs the predicted value: 13998.0
# The difference is: [0.]
#
# Original value: [36995] vs the predicted value: 39000.0
# The difference is: [-2005.]
#
# Original value: [16490] vs the predicted value: 17763.5
# The difference is: [-1273.5]
#
# Original value: [14498] vs the predicted value: 16710.0
# The difference is: [-2212.]
#
# Original value: [29300] vs the predicted value: 27872.5
# The difference is: [1427.5]
#
# Original value: [18487] vs the predicted value: 16997.0
# The difference is: [1490.]
#
# Original value: [27500] vs the predicted value: 26490.0
# The difference is: [1010.]
#
# Original value: [9898] vs the predicted value: 11295.0
# The difference is: [-1397.]
#
# Original value: [10498] vs the predicted value: 12781.0
# The difference is: [-2283.]
#
# Original value: [44999] vs the predicted value: 43946.0
# The difference is: [1053.]
#
# Original value: [11650] vs the predicted value: 10650.0
# The difference is: [1000.]
#
# Original value: [24975] vs the predicted value: 30936.5
# The difference is: [-5961.5]
#
# Original value: [13495] vs the predicted value: 14148.5
# The difference is: [-653.5]
#
# Original value: [16000] vs the predicted value: 16995.0
# The difference is: [-995.]
#
# Original value: [30500] vs the predicted value: 26122.5
# The difference is: [4377.5]
#
# Original value: [8900] vs the predicted value: 11975.0
# The difference is: [-3075.]
#
# Original value: [45912] vs the predicted value: 41990.0
# The difference is: [3922.]
#
# Original value: [15998] vs the predicted value: 15495.5
# The difference is: [502.5]
#
# Original value: [27444] vs the predicted value: 27212.0
# The difference is: [232.]
#
# Original value: [40000] vs the predicted value: 34995.0
# The difference is: [5005.]
#
# Original value: [14999] vs the predicted value: 23490.0
# The difference is: [-8491.]
#
# Original value: [25500] vs the predicted value: 25008.0
# The difference is: [492.]
#
# Original value: [23950] vs the predicted value: 23995.0
# The difference is: [-45.]
#
# Original value: [28985] vs the predicted value: 24215.5
# The difference is: [4769.5]
#
# Original value: [12816] vs the predicted value: 11395.0
# The difference is: [1421.]
#
# Original value: [21990] vs the predicted value: 21122.5
# The difference is: [867.5]
#
# Original value: [20000] vs the predicted value: 18995.0
# The difference is: [1005.]
#
# Original value: [13750] vs the predicted value: 13554.0
# The difference is: [196.]
#
# Original value: [18192] vs the predicted value: 16490.0
# The difference is: [1702.]
#
# Original value: [21755] vs the predicted value: 20492.5
# The difference is: [1262.5]
#
# Original value: [18998] vs the predicted value: 17498.0
# The difference is: [1500.]
#
# Original value: [12505] vs the predicted value: 12398.0
# The difference is: [107.]
#
# Original value: [18495] vs the predicted value: 19995.0
# The difference is: [-1500.]
#
# Original value: [12300] vs the predicted value: 10465.0
# The difference is: [1835.]
#
# Original value: [21000] vs the predicted value: 16500.0
# The difference is: [4500.]
#
# Original value: [35500] vs the predicted value: 35500.0
# The difference is: [0.]
#
# Original value: [8354] vs the predicted value: 8995.0
# The difference is: [-641.]
#
# Original value: [22498] vs the predicted value: 22490.5
# The difference is: [7.5]
#
# Original value: [21241] vs the predicted value: 24291.0
# The difference is: [-3050.]
#
# Original value: [49990] vs the predicted value: 47250.0
# The difference is: [2740.]
#
# Original value: [37800] vs the predicted value: 35888.0
# The difference is: [1912.]
#
# Original value: [22500] vs the predicted value: 20492.5
# The difference is: [2007.5]
#
# Original value: [12490] vs the predicted value: 17747.0
# The difference is: [-5257.]
#
# Original value: [27000] vs the predicted value: 31245.5
# The difference is: [-4245.5]
#
# Original value: [13495] vs the predicted value: 14692.5
# The difference is: [-1197.5]
#
# Original value: [16790] vs the predicted value: 16144.0
# The difference is: [646.]
#
# Original value: [21490] vs the predicted value: 22183.0
# The difference is: [-693.]
#
# Original value: [11998] vs the predicted value: 14810.0
# The difference is: [-2812.]
#
# Original value: [28500] vs the predicted value: 28766.0
# The difference is: [-266.]
#
# Original value: [25444] vs the predicted value: 24258.5
# The difference is: [1185.5]
#
# Original value: [29490] vs the predicted value: 34995.0
# The difference is: [-5505.]
#
# Original value: [15480] vs the predicted value: 14320.0
# The difference is: [1160.]
#
# Original value: [24990] vs the predicted value: 26296.0
# The difference is: [-1306.]
#
# Original value: [16000] vs the predicted value: 12995.0
# The difference is: [3005.]
#
# Original value: [13995] vs the predicted value: 9698.0
# The difference is: [4297.]
#
# Original value: [11690] vs the predicted value: 11130.0
# The difference is: [560.]
#
# Original value: [70990] vs the predicted value: 60948.0
# The difference is: [10042.]
#
# Original value: [13499] vs the predicted value: 13995.0
# The difference is: [-496.]
#
# Original value: [17300] vs the predicted value: 16498.0
# The difference is: [802.]
#
# Original value: [45990] vs the predicted value: 43940.0
# The difference is: [2050.]
#
# Original value: [22000] vs the predicted value: 22991.0
# The difference is: [-991.]
#
# Original value: [31795] vs the predicted value: 33995.0
# The difference is: [-2200.]
#
# Original value: [10291] vs the predicted value: 10000.0
# The difference is: [291.]
#
# Original value: [7700] vs the predicted value: 7729.0
# The difference is: [-29.]
#
# Original value: [12998] vs the predicted value: 11750.0
# The difference is: [1248.]
#
# Original value: [14992] vs the predicted value: 18505.0
# The difference is: [-3513.]
#
# Original value: [21250] vs the predicted value: 21242.5
# The difference is: [7.5]
#
# Original value: [21991] vs the predicted value: 22245.0
# The difference is: [-254.]
#
# Original value: [15000] vs the predicted value: 15495.5
# The difference is: [-495.5]
#
# Original value: [29490] vs the predicted value: 34320.0
# The difference is: [-4830.]
#
# Original value: [18990] vs the predicted value: 15498.0
# The difference is: [3492.]
#
# Original value: [62990] vs the predicted value: 59990.0
# The difference is: [3000.]
#
# Original value: [27312] vs the predicted value: 31242.5
# The difference is: [-3930.5]
#
# Original value: [12298] vs the predicted value: 12646.5
# The difference is: [-348.5]
#
# Original value: [12700] vs the predicted value: 11750.0
# The difference is: [950.]
#
# Original value: [41000] vs the predicted value: 39995.0
# The difference is: [1005.]
#
# Original value: [32000] vs the predicted value: 30288.0
# The difference is: [1712.]
#
# Original value: [33490] vs the predicted value: 32723.0
# The difference is: [767.]
#
# Original value: [17012] vs the predicted value: 16999.0
# The difference is: [13.]
#
# Original value: [11990] vs the predicted value: 17950.0
# The difference is: [-5960.]
#
# Original value: [45000] vs the predicted value: 42500.0
# The difference is: [2500.]
#
# Original value: [16600] vs the predicted value: 16245.0
# The difference is: [355.]
#
# Original value: [31000] vs the predicted value: 28844.0
# The difference is: [2156.]
#
# Original value: [11850] vs the predicted value: 9495.0
# The difference is: [2355.]
#
# Original value: [17491] vs the predicted value: 16406.0
# The difference is: [1085.]
#
# Original value: [11799] vs the predicted value: 11124.0
# The difference is: [675.]
#
# Original value: [15991] vs the predicted value: 16470.0
# The difference is: [-479.]
#
# Original value: [19500] vs the predicted value: 17998.5
# The difference is: [1501.5]
#
# Original value: [9500] vs the predicted value: 8874.0
# The difference is: [626.]
#
# Original value: [15490] vs the predicted value: 14498.0
# The difference is: [992.]
#
# Original value: [13495] vs the predicted value: 14145.0
# The difference is: [-650.]
#
# Original value: [37000] vs the predicted value: 29170.5
# The difference is: [7829.5]
#
# Original value: [18650] vs the predicted value: 19870.5
# The difference is: [-1220.5]
#
# Original value: [14490] vs the predicted value: 13990.0
# The difference is: [500.]
#
# Original value: [36990] vs the predicted value: 39700.0
# The difference is: [-2710.]
#
# Original value: [35422] vs the predicted value: 36819.5
# The difference is: [-1397.5]
#
# Original value: [16498] vs the predicted value: 19294.5
# The difference is: [-2796.5]
#
# Original value: [26846] vs the predicted value: 25441.5
# The difference is: [1404.5]
#
# Original value: [15995] vs the predicted value: 14675.0
# The difference is: [1320.]
#
# Original value: [36497] vs the predicted value: 35990.0
# The difference is: [507.]
#
# Original value: [20698] vs the predicted value: 19746.5
# The difference is: [951.5]
#
# Original value: [21990] vs the predicted value: 17932.5
# The difference is: [4057.5]
#
# Original value: [31516] vs the predicted value: 29990.0
# The difference is: [1526.]
#
# Original value: [24490] vs the predicted value: 26011.0
# The difference is: [-1521.]
#
# Original value: [25998] vs the predicted value: 28974.0
# The difference is: [-2976.]
#
# Original value: [31995] vs the predicted value: 36997.5
# The difference is: [-5002.5]
#
# Original value: [26888] vs the predicted value: 26995.0
# The difference is: [-107.]
#
# Original value: [34256] vs the predicted value: 37920.5
# The difference is: [-3664.5]
#
# Original value: [15698] vs the predicted value: 15496.5
# The difference is: [201.5]
#
# Original value: [20000] vs the predicted value: 19993.0
# The difference is: [7.]
#
# Original value: [10100] vs the predicted value: 10100.0
# The difference is: [0.]
#
# Original value: [23990] vs the predicted value: 20850.0
# The difference is: [3140.]
#
# Original value: [10800] vs the predicted value: 9498.0
# The difference is: [1302.]
#
# Original value: [34000] vs the predicted value: 33444.0
# The difference is: [556.]
#
# Original value: [16991] vs the predicted value: 16998.0
# The difference is: [-7.]
#
# Original value: [21000] vs the predicted value: 21000.0
# The difference is: [0.]
#
# Original value: [22000] vs the predicted value: 20991.0
# The difference is: [1009.]
#
# Original value: [23985] vs the predicted value: 18750.0
# The difference is: [5235.]
#
# Original value: [15763] vs the predicted value: 17496.5
# The difference is: [-1733.5]
#
# Original value: [16730] vs the predicted value: 17940.0
# The difference is: [-1210.]
#
# Original value: [24995] vs the predicted value: 22490.0
# The difference is: [2505.]
#
# Original value: [16297] vs the predicted value: 15490.0
# The difference is: [807.]
#
# Original value: [21288] vs the predicted value: 21691.0
# The difference is: [-403.]
#
# Original value: [11998] vs the predicted value: 12498.0
# The difference is: [-500.]
#
# Original value: [38750] vs the predicted value: 39245.5
# The difference is: [-495.5]
#
# Original value: [28470] vs the predicted value: 26742.5
# The difference is: [1727.5]
#
# Original value: [11980] vs the predicted value: 11795.0
# The difference is: [185.]
#
# Original value: [29980] vs the predicted value: 28242.5
# The difference is: [1737.5]
#
# Original value: [34995] vs the predicted value: 31900.0
# The difference is: [3095.]
#
# Original value: [14498] vs the predicted value: 16870.5
# The difference is: [-2372.5]
#
# Original value: [23991] vs the predicted value: 25925.0
# The difference is: [-1934.]
#
# Original value: [35866] vs the predicted value: 39492.5
# The difference is: [-3626.5]
#
# Original value: [27991] vs the predicted value: 27409.0
# The difference is: [582.]
#
# Original value: [10970] vs the predicted value: 10291.0
# The difference is: [679.]
#
# Original value: [24990] vs the predicted value: 22850.0
# The difference is: [2140.]
#
# Original value: [41495] vs the predicted value: 35650.0
# The difference is: [5845.]
#
# Original value: [19995] vs the predicted value: 14491.0
# The difference is: [5504.]
#
# Original value: [22995] vs the predicted value: 18880.0
# The difference is: [4115.]
#
# Original value: [16800] vs the predicted value: 16745.0
# The difference is: [55.]
#
# Original value: [40000] vs the predicted value: 34873.0
# The difference is: [5127.]
#
# Original value: [22444] vs the predicted value: 19870.5
# The difference is: [2573.5]
#
# Original value: [32490] vs the predicted value: 37995.0
# The difference is: [-5505.]
#
# Original value: [12799] vs the predicted value: 15620.0
# The difference is: [-2821.]
#
# Original value: [32098] vs the predicted value: 30825.0
# The difference is: [1273.]
#
# Original value: [18488] vs the predicted value: 16436.0
# The difference is: [2052.]
#
# Original value: [54490] vs the predicted value: 57995.0
# The difference is: [-3505.]
#
# Original value: [18327] vs the predicted value: 18595.0
# The difference is: [-268.]
#
# Original value: [38990] vs the predicted value: 39990.0
# The difference is: [-1000.]
#
# Original value: [19990] vs the predicted value: 21244.0
# The difference is: [-1254.]
#
# Original value: [20890] vs the predicted value: 20650.0
# The difference is: [240.]
#
# Original value: [37507] vs the predicted value: 26645.0
# The difference is: [10862.]
#
# Original value: [19440] vs the predicted value: 18142.5
# The difference is: [1297.5]
#
# Original value: [12999] vs the predicted value: 13542.5
# The difference is: [-543.5]
#
# Original value: [41606] vs the predicted value: 39967.5
# The difference is: [1638.5]
#
# Original value: [34990] vs the predicted value: 35323.333333333336
# The difference is: [-333.33333333]
#
# Original value: [19990] vs the predicted value: 19490.0
# The difference is: [500.]
#
# Original value: [15495] vs the predicted value: 13998.0
# The difference is: [1497.]
#
# Original value: [29256] vs the predicted value: 31245.0
# The difference is: [-1989.]
#
# Original value: [26846] vs the predicted value: 25491.0
# The difference is: [1355.]
#
# Original value: [13995] vs the predicted value: 13491.0
# The difference is: [504.]
#
# Original value: [13995] vs the predicted value: 14945.0
# The difference is: [-950.]
#
# Original value: [36000] vs the predicted value: 32500.0
# The difference is: [3500.]
#
# Original value: [19100] vs the predicted value: 24477.0
# The difference is: [-5377.]
#
# Original value: [20000] vs the predicted value: 18892.5
# The difference is: [1107.5]
#
# Original value: [18500] vs the predicted value: 19245.0
# The difference is: [-745.]
#
# Original value: [11210] vs the predicted value: 9798.0
# The difference is: [1412.]
#
# Original value: [30888] vs the predicted value: 34990.0
# The difference is: [-4102.]
#
# Original value: [22795] vs the predicted value: 23120.0
# The difference is: [-325.]
#
# Original value: [22383] vs the predicted value: 22745.5
# The difference is: [-362.5]
#
# Original value: [20495] vs the predicted value: 21000.0
# The difference is: [-505.]
#
# Original value: [27991] vs the predicted value: 29329.0
# The difference is: [-1338.]
#
# Original value: [54950] vs the predicted value: 52458.5
# The difference is: [2491.5]
#
# Original value: [24991] vs the predicted value: 23985.0
# The difference is: [1006.]
#
# Original value: [18695] vs the predicted value: 18995.0
# The difference is: [-300.]
#
# Original value: [36990] vs the predicted value: 34491.0
# The difference is: [2499.]
#
# Original value: [35495] vs the predicted value: 33630.0
# The difference is: [1865.]
#
# Original value: [25636] vs the predicted value: 26410.5
# The difference is: [-774.5]
#
# Original value: [11930] vs the predicted value: 11895.0
# The difference is: [35.]
#
# Original value: [19500] vs the predicted value: 17397.5
# The difference is: [2102.5]
#
# Original value: [20344] vs the predicted value: 21244.0
# The difference is: [-900.]
#
# Original value: [32195] vs the predicted value: 29996.0
# The difference is: [2199.]
#
# Original value: [27495] vs the predicted value: 26717.0
# The difference is: [778.]
#
# Original value: [17756] vs the predicted value: 20000.0
# The difference is: [-2244.]
#
# Original value: [27001] vs the predicted value: 27495.0
# The difference is: [-494.]
#
# Original value: [29495] vs the predicted value: 37743.0
# The difference is: [-8248.]
#
# Original value: [13498] vs the predicted value: 13345.0
# The difference is: [153.]
#
# Original value: [23142] vs the predicted value: 22246.5
# The difference is: [895.5]
#
# Original value: [21500] vs the predicted value: 24495.0
# The difference is: [-2995.]
#
# Original value: [49850] vs the predicted value: 47250.0
# The difference is: [2600.]
#
# Original value: [35490] vs the predicted value: 38495.0
# The difference is: [-3005.]
#
# Original value: [27246] vs the predicted value: 31745.5
# The difference is: [-4499.5]
#
# Original value: [10598] vs the predicted value: 10093.0
# The difference is: [505.]
#
# Original value: [19755] vs the predicted value: 19496.0
# The difference is: [259.]
#
# Original value: [14700] vs the predicted value: 13300.0
# The difference is: [1400.]
#
# Original value: [18350] vs the predicted value: 24698.0
# The difference is: [-6348.]
#
# Original value: [9580] vs the predicted value: 11124.0
# The difference is: [-1544.]
#
# Original value: [12881] vs the predicted value: 12112.5
# The difference is: [768.5]
#
# Original value: [19686] vs the predicted value: 17298.0
# The difference is: [2388.]
#
# Original value: [18000] vs the predicted value: 16389.0
# The difference is: [1611.]
#
# Original value: [16995] vs the predicted value: 17496.5
# The difference is: [-501.5]
#
# Original value: [27990] vs the predicted value: 31242.5
# The difference is: [-3252.5]
#
# Original value: [17985] vs the predicted value: 21497.5
# The difference is: [-3512.5]
#
# Original value: [19450] vs the predicted value: 19496.0
# The difference is: [-46.]
#
# Original value: [28990] vs the predicted value: 31439.0
# The difference is: [-2449.]
#
# Original value: [18998] vs the predicted value: 18500.0
# The difference is: [498.]
#
# Original value: [18000] vs the predicted value: 21691.0
# The difference is: [-3691.]
#
# Original value: [21850] vs the predicted value: 18074.5
# The difference is: [3775.5]
#
# Original value: [12750] vs the predicted value: 13500.0
# The difference is: [-750.]
#
# Original value: [20000] vs the predicted value: 19995.0
# The difference is: [5.]
#
# Original value: [20250] vs the predicted value: 16436.0
# The difference is: [3814.]
#
# Original value: [20962] vs the predicted value: 18647.0
# The difference is: [2315.]
#
# Original value: [12000] vs the predicted value: 11100.5
# The difference is: [899.5]
#
# Original value: [34890] vs the predicted value: 35750.0
# The difference is: [-860.]
#
# Original value: [12372] vs the predicted value: 12875.5
# The difference is: [-503.5]
#
# Original value: [22000] vs the predicted value: 22444.0
# The difference is: [-444.]
#
# Original value: [24990] vs the predicted value: 25496.0
# The difference is: [-506.]
#
# Original value: [55500] vs the predicted value: 59870.0
# The difference is: [-4370.]
#
# Original value: [17498] vs the predicted value: 17747.5
# The difference is: [-249.5]
#
# Original value: [28770] vs the predicted value: 27995.0
# The difference is: [775.]
#
# Original value: [19990] vs the predicted value: 20990.0
# The difference is: [-1000.]
#
# Original value: [57990] vs the predicted value: 66990.0
# The difference is: [-9000.]
#
# Original value: [10500] vs the predicted value: 13992.5
# The difference is: [-3492.5]
#
# Original value: [16600] vs the predicted value: 22230.0
# The difference is: [-5630.]
#
# Original value: [12070] vs the predicted value: 13995.0
# The difference is: [-1925.]
#
# Original value: [21985] vs the predicted value: 22000.0
# The difference is: [-15.]
#
# Original value: [21499] vs the predicted value: 20756.5
# The difference is: [742.5]
#
# Original value: [24395] vs the predicted value: 25780.0
# The difference is: [-1385.]
#
# Original value: [42995] vs the predicted value: 36740.0
# The difference is: [6255.]
#
# Original value: [22669] vs the predicted value: 23000.0
# The difference is: [-331.]
#
# Original value: [10295] vs the predicted value: 17950.0
# The difference is: [-7655.]
#
# Original value: [20298] vs the predicted value: 22036.0
# The difference is: [-1738.]
#
# Original value: [26795] vs the predicted value: 24699.0
# The difference is: [2096.]
#
# Original value: [49995] vs the predicted value: 55823.333333333336
# The difference is: [-5828.33333333]
#
# Original value: [21995] vs the predicted value: 14997.0
# The difference is: [6998.]
#
# Original value: [14590] vs the predicted value: 13610.0
# The difference is: [980.]
#
# Original value: [24200] vs the predicted value: 23780.0
# The difference is: [420.]
#
# Original value: [19498] vs the predicted value: 17637.0
# The difference is: [1861.]
#
# Original value: [46888] vs the predicted value: 43940.0
# The difference is: [2948.]
#
# Original value: [19790] vs the predicted value: 20200.0
# The difference is: [-410.]
#
# Original value: [13250] vs the predicted value: 12998.0
# The difference is: [252.]
#
# Original value: [17498] vs the predicted value: 15775.0
# The difference is: [1723.]
#
# Original value: [49990] vs the predicted value: 45991.0
# The difference is: [3999.]
#
# Original value: [19995] vs the predicted value: 20560.0
# The difference is: [-565.]
#
# Original value: [39000] vs the predicted value: 51745.0
# The difference is: [-12745.]
#
# Original value: [22003] vs the predicted value: 21139.5
# The difference is: [863.5]
#
# Original value: [17000] vs the predicted value: 13180.0
# The difference is: [3820.]
#
# Original value: [37902] vs the predicted value: 39700.0
# The difference is: [-1798.]
#
# Original value: [19890] vs the predicted value: 17498.0
# The difference is: [2392.]
#
# Original value: [21032] vs the predicted value: 23947.5
# The difference is: [-2915.5]
#
# Original value: [20000] vs the predicted value: 23955.0
# The difference is: [-3955.]
#
# Original value: [10499] vs the predicted value: 9658.5
# The difference is: [840.5]
#
# Original value: [18995] vs the predicted value: 17998.0
# The difference is: [997.]
#
# Original value: [18298] vs the predicted value: 17397.5
# The difference is: [900.5]
#
# Original value: [19498] vs the predicted value: 18713.5
# The difference is: [784.5]
#
# Original value: [21495] vs the predicted value: 23472.0
# The difference is: [-1977.]
#
# Original value: [9000] vs the predicted value: 8894.5
# The difference is: [105.5]
#
# Original value: [60995] vs the predicted value: 55500.0
# The difference is: [5495.]
#
# Original value: [29980] vs the predicted value: 30445.5
# The difference is: [-465.5]
#
# Original value: [20650] vs the predicted value: 22172.5
# The difference is: [-1522.5]
#
# Original value: [9649] vs the predicted value: 9150.5
# The difference is: [498.5]
#
# Original value: [37888] vs the predicted value: 37750.0
# The difference is: [138.]
#
# Original value: [19000] vs the predicted value: 19400.5
# The difference is: [-400.5]
#
# Original value: [17691] vs the predicted value: 22230.0
# The difference is: [-4539.]
#
# Original value: [11495] vs the predicted value: 11795.0
# The difference is: [-300.]
#
# Original value: [32990] vs the predicted value: 30550.0
# The difference is: [2440.]
#
# Original value: [16998] vs the predicted value: 16740.5
# The difference is: [257.5]
#
# Original value: [31985] vs the predicted value: 30445.5
# The difference is: [1539.5]
#
# Original value: [17495] vs the predicted value: 13250.0
# The difference is: [4245.]
#
# Original value: [16300] vs the predicted value: 18740.0
# The difference is: [-2440.]
#
# Original value: [22995] vs the predicted value: 23955.0
# The difference is: [-960.]
#
# Original value: [12495] vs the predicted value: 12995.0
# The difference is: [-500.]
#
# Original value: [17190] vs the predicted value: 16999.0
# The difference is: [191.]
#
# Original value: [16495] vs the predicted value: 15791.0
# The difference is: [704.]
#
# Original value: [8300] vs the predicted value: 8000.0
# The difference is: [300.]
#
# Original value: [18495] vs the predicted value: 19995.0
# The difference is: [-1500.]
#
# Original value: [43490] vs the predicted value: 42941.5
# The difference is: [548.5]
#
# Original value: [18401] vs the predicted value: 19496.0
# The difference is: [-1095.]
#
# Original value: [16495] vs the predicted value: 12645.0
# The difference is: [3850.]
#
# Original value: [19998] vs the predicted value: 20128.0
# The difference is: [-130.]
#
# Original value: [28495] vs the predicted value: 25491.0
# The difference is: [3004.]
#
# Original value: [23700] vs the predicted value: 36990.0
# The difference is: [-13290.]
#
# Original value: [63912] vs the predicted value: 64842.0
# The difference is: [-930.]
#
# Original value: [14995] vs the predicted value: 18500.0
# The difference is: [-3505.]
#
# Original value: [36989] vs the predicted value: 36819.5
# The difference is: [169.5]
#
# Original value: [21991] vs the predicted value: 19946.5
# The difference is: [2044.5]
#
# Original value: [33499] vs the predicted value: 33242.5
# The difference is: [256.5]
#
# Original value: [12998] vs the predicted value: 12649.0
# The difference is: [349.]
#
# Original value: [14498] vs the predicted value: 15965.0
# The difference is: [-1467.]
#
# Original value: [18950] vs the predicted value: 24985.0
# The difference is: [-6035.]
#
# Original value: [12650] vs the predicted value: 13345.0
# The difference is: [-695.]
#
# Original value: [16400] vs the predicted value: 15791.0
# The difference is: [609.]
#
# Original value: [20491] vs the predicted value: 19939.0
# The difference is: [552.]
#
# Original value: [14995] vs the predicted value: 13234.5
# The difference is: [1760.5]
#
# Original value: [46000] vs the predicted value: 47972.5
# The difference is: [-1972.5]
#
# Original value: [14495] vs the predicted value: 14399.0
# The difference is: [96.]
#
# Original value: [11999] vs the predicted value: 11695.0
# The difference is: [304.]
#
# Original value: [10495] vs the predicted value: 10716.0
# The difference is: [-221.]
#
# Original value: [12500] vs the predicted value: 12876.5
# The difference is: [-376.5]
#
# Original value: [22061] vs the predicted value: 21691.0
# The difference is: [370.]
#
# Original value: [42995] vs the predicted value: 42440.0
# The difference is: [555.]
#
# Original value: [20990] vs the predicted value: 20498.0
# The difference is: [492.]
#
# Original value: [10552] vs the predicted value: 10774.0
# The difference is: [-222.]
#
# Original value: [18181] vs the predicted value: 15498.0
# The difference is: [2683.]
#
# Original value: [28990] vs the predicted value: 29250.0
# The difference is: [-260.]
#
# Original value: [15995] vs the predicted value: 22750.0
# The difference is: [-6755.]
#
# Original value: [14650] vs the predicted value: 20300.0
# The difference is: [-5650.]
#
# Original value: [35490] vs the predicted value: 39990.0
# The difference is: [-4500.]
#
# Original value: [36400] vs the predicted value: 38990.0
# The difference is: [-2590.]
#
# Original value: [14495] vs the predicted value: 15998.0
# The difference is: [-1503.]
#
# Original value: [19990] vs the predicted value: 21498.0
# The difference is: [-1508.]
#
# Original value: [19490] vs the predicted value: 17420.0
# The difference is: [2070.]
#
# Original value: [27000] vs the predicted value: 26950.0
# The difference is: [50.]
#
# Original value: [38995] vs the predicted value: 37995.0
# The difference is: [1000.]
#
# Original value: [25498] vs the predicted value: 29152.0
# The difference is: [-3654.]
#
# Original value: [22490] vs the predicted value: 22913.5
# The difference is: [-423.5]
#
# Original value: [19599] vs the predicted value: 18595.0
# The difference is: [1004.]
#
# Original value: [18998] vs the predicted value: 16600.0
# The difference is: [2398.]
#
# Original value: [17797] vs the predicted value: 17322.0
# The difference is: [475.]
#
# Original value: [20000] vs the predicted value: 21995.0
# The difference is: [-1995.]
#
# Original value: [24998] vs the predicted value: 23998.0
# The difference is: [1000.]
#
# Original value: [43490] vs the predicted value: 43490.0
# The difference is: [0.]
#
# Original value: [12698] vs the predicted value: 9490.0
# The difference is: [3208.]
#
# Original value: [18000] vs the predicted value: 18749.0
# The difference is: [-749.]
#
# Original value: [10998] vs the predicted value: 17870.0
# The difference is: [-6872.]
#
# Original value: [23165] vs the predicted value: 21444.0
# The difference is: [1721.]
#
# Original value: [44999] vs the predicted value: 48206.0
# The difference is: [-3207.]
#
# Original value: [15670] vs the predicted value: 16498.0
# The difference is: [-828.]
#
# Original value: [44990] vs the predicted value: 48260.5
# The difference is: [-3270.5]
#
# Original value: [24998] vs the predicted value: 27985.0
# The difference is: [-2987.]
#
# Original value: [16380] vs the predicted value: 16999.0
# The difference is: [-619.]
#
# Original value: [15141] vs the predicted value: 14148.5
# The difference is: [992.5]
#
# Original value: [25750] vs the predicted value: 36443.0
# The difference is: [-10693.]
#
# Original value: [32000] vs the predicted value: 32922.5
# The difference is: [-922.5]
#
# Original value: [27991] vs the predicted value: 31985.0
# The difference is: [-3994.]
#
# Original value: [10330] vs the predicted value: 12112.5
# The difference is: [-1782.5]
#
# Original value: [21491] vs the predicted value: 21691.0
# The difference is: [-200.]
#
# Original value: [12491] vs the predicted value: 12484.5
# The difference is: [6.5]
#
# Original value: [25490] vs the predicted value: 27990.0
# The difference is: [-2500.]
#
# Original value: [20490] vs the predicted value: 21624.0
# The difference is: [-1134.]
#
# Original value: [18950] vs the predicted value: 18674.0
# The difference is: [276.]
#
# Original value: [31995] vs the predicted value: 31900.0
# The difference is: [95.]
#
# Original value: [18990] vs the predicted value: 14998.0
# The difference is: [3992.]
#
# Original value: [24500] vs the predicted value: 29056.0
# The difference is: [-4556.]
#
# Original value: [48950] vs the predicted value: 48206.0
# The difference is: [744.]
#
# Original value: [10999] vs the predicted value: 13498.0
# The difference is: [-2499.]
#
# Original value: [11995] vs the predicted value: 10379.0
# The difference is: [1616.]
#
# Original value: [12995] vs the predicted value: 12495.0
# The difference is: [500.]
#
# Original value: [20999] vs the predicted value: 18892.5
# The difference is: [2106.5]
#
# Original value: [22444] vs the predicted value: 20290.0
# The difference is: [2154.]
#
# Original value: [22990] vs the predicted value: 30990.0
# The difference is: [-8000.]
#
# Original value: [45000] vs the predicted value: 43490.0
# The difference is: [1510.]
#
# Original value: [14898] vs the predicted value: 13992.5
# The difference is: [905.5]
#
# Original value: [18772] vs the predicted value: 18505.0
# The difference is: [267.]
#
# Original value: [18495] vs the predicted value: 19995.0
# The difference is: [-1500.]
#
# Original value: [21465] vs the predicted value: 20489.5
# The difference is: [975.5]
#
# Original value: [21490] vs the predicted value: 21995.0
# The difference is: [-505.]
#
# Original value: [17650] vs the predicted value: 16724.0
# The difference is: [926.]
#
# Original value: [20495] vs the predicted value: 21995.0
# The difference is: [-1500.]
#
# Original value: [28490] vs the predicted value: 27842.5
# The difference is: [647.5]
#
# Original value: [18495] vs the predicted value: 17400.0
# The difference is: [1095.]
#
# Original value: [11107] vs the predicted value: 13234.5
# The difference is: [-2127.5]
#
# Original value: [33295] vs the predicted value: 31156.0
# The difference is: [2139.]
#
# Original value: [13890] vs the predicted value: 14993.5
# The difference is: [-1103.5]
#
# Original value: [22650] vs the predicted value: 18839.0
# The difference is: [3811.]
#
# Original value: [9270] vs the predicted value: 14298.0
# The difference is: [-5028.]
#
# Original value: [12270] vs the predicted value: 13500.0
# The difference is: [-1230.]
#
# Original value: [12950] vs the predicted value: 12343.0
# The difference is: [607.]
#
# Original value: [19655] vs the predicted value: 21195.0
# The difference is: [-1540.]
#
# Original value: [22480] vs the predicted value: 22302.0
# The difference is: [178.]
#
# ...
#
# Original value: [22500] vs the predicted value: 23995.0
# The difference is: [-1495.]
#
# Original value: [26995] vs the predicted value: 28245.0
# The difference is: [-1250.]
#
# Original value: [11495] vs the predicted value: 11894.5
# The difference is: [-399.5]
#
# Original value: [21200] vs the predicted value: 18870.0
# The difference is: [2330.]
#
# Original value: [10260] vs the predicted value: 12000.0
# The difference is: [-1740.]
#
# Original value: [17649] vs the predicted value: 20465.0
# The difference is: [-2816.]
#
# Original value: [27000] vs the predicted value: 25000.0
# The difference is: [2000.]
#
# Original value: [60990] vs the predicted value: 66990.0
# The difference is: [-6000.]
#
# Original value: [17990] vs the predicted value: 8695.0
# The difference is: [9295.]
#
# Original value: [14899] vs the predicted value: 16994.0
# The difference is: [-2095.]
#
# Original value: [30870] vs the predicted value: 26990.0
# The difference is: [3880.]
#
# Original value: [23450] vs the predicted value: 23300.0
# The difference is: [150.]
#
# Original value: [109990] vs the predicted value: 115490.0
# The difference is: [-5500.]
#
# Original value: [27990] vs the predicted value: 27745.0
# The difference is: [245.]
#
# Original value: [17397] vs the predicted value: 18700.0
# The difference is: [-1303.]
#
# Original value: [31072] vs the predicted value: 29170.5
# The difference is: [1901.5]
#
# Original value: [17490] vs the predicted value: 15995.0
# The difference is: [1495.]
#
# Original value: [26490] vs the predicted value: 27745.0
# The difference is: [-1255.]
#
# Original value: [19472] vs the predicted value: 17637.0
# The difference is: [1835.]
#
# Original value: [14242] vs the predicted value: 13998.0
# The difference is: [244.]
#
# Original value: [21000] vs the predicted value: 19999.0
# The difference is: [1001.]
#
# Original value: [18500] vs the predicted value: 17972.5
# The difference is: [527.5]
#
# Original value: [17790] vs the predicted value: 14928.0
# The difference is: [2862.]
#
# Original value: [39996] vs the predicted value: 39982.5
# The difference is: [13.5]
#
# Original value: [18990] vs the predicted value: 19998.0
# The difference is: [-1008.]
#
# Original value: [35998] vs the predicted value: 34998.0
# The difference is: [1000.]
#
# Original value: [36985] vs the predicted value: 32723.0
# The difference is: [4262.]
#
# Original value: [51495] vs the predicted value: 53990.0
# The difference is: [-2495.]
#
# Original value: [47990] vs the predicted value: 42840.0
# The difference is: [5150.]
#
# Original value: [27850] vs the predicted value: 34491.0
# The difference is: [-6641.]
#
# Original value: [16690] vs the predicted value: 14700.0
# The difference is: [1990.]
#
# Original value: [10395] vs the predicted value: 8894.5
# The difference is: [1500.5]
#
# Original value: [25495] vs the predicted value: 30717.5
# The difference is: [-5222.5]
#
# Original value: [14698] vs the predicted value: 15872.5
# The difference is: [-1174.5]
#
# Original value: [31998] vs the predicted value: 31698.0
# The difference is: [300.]
#
# Original value: [24368] vs the predicted value: 19939.0
# The difference is: [4429.]
#
# Original value: [47990] vs the predicted value: 45492.5
# The difference is: [2497.5]
#
# Original value: [93950] vs the predicted value: 129000.0
# The difference is: [-35050.]
#
# Original value: [16995] vs the predicted value: 18990.0
# The difference is: [-1995.]
#
# Original value: [15500] vs the predicted value: 16491.5
# The difference is: [-991.5]
#
# Original value: [17498] vs the predicted value: 16998.0
# The difference is: [500.]
#
# Original value: [29000] vs the predicted value: 34765.5
# The difference is: [-5765.5]
#
# Original value: [17995] vs the predicted value: 17498.0
# The difference is: [497.]
#
# Original value: [11798] vs the predicted value: 9448.5
# The difference is: [2349.5]
#
# Original value: [24000] vs the predicted value: 22000.0
# The difference is: [2000.]
#
# Original value: [18298] vs the predicted value: 18995.0
# The difference is: [-697.]
#
# Original value: [36000] vs the predicted value: 37497.5
# The difference is: [-1497.5]
#
# Original value: [18995] vs the predicted value: 19999.0
# The difference is: [-1004.]
#
# Original value: [20597] vs the predicted value: 25498.0
# The difference is: [-4901.]
#
# Original value: [14995] vs the predicted value: 12992.5
# The difference is: [2002.5]
#
# Original value: [19995] vs the predicted value: 19730.5
# The difference is: [264.5]
#
# Original value: [22988] vs the predicted value: 22741.0
# The difference is: [247.]
#
# Original value: [35850] vs the predicted value: 29786.0
# The difference is: [6064.]
#
# Original value: [19998] vs the predicted value: 18443.0
# The difference is: [1555.]
#
# Original value: [29985] vs the predicted value: 20495.0
# The difference is: [9490.]
#
# Original value: [32995] vs the predicted value: 32992.5
# The difference is: [2.5]
#
# Original value: [30850] vs the predicted value: 29990.0
# The difference is: [860.]
#
# Original value: [13495] vs the predicted value: 17950.0
# The difference is: [-4455.]
#
# Original value: [15052] vs the predicted value: 12646.5
# The difference is: [2405.5]
#
# Original value: [42500] vs the predicted value: 44990.0
# The difference is: [-2490.]
#
# Original value: [19490] vs the predicted value: 16995.0
# The difference is: [2495.]
#
# Original value: [26890] vs the predicted value: 22943.0
# The difference is: [3947.]
#
# Original value: [21656] vs the predicted value: 19939.0
# The difference is: [1717.]
#
# Original value: [21644] vs the predicted value: 19345.0
# The difference is: [2299.]
#
# Original value: [28062] vs the predicted value: 25212.0
# The difference is: [2850.]
#
# Original value: [27995] vs the predicted value: 28471.0
# The difference is: [-476.]
#
# Original value: [9430] vs the predicted value: 10260.0
# The difference is: [-830.]
#
# Original value: [24490] vs the predicted value: 23780.0
# The difference is: [710.]
#
# Original value: [35989] vs the predicted value: 36819.5
# The difference is: [-830.5]
#
# Original value: [11966] vs the predicted value: 12146.5
# The difference is: [-180.5]
#
# Original value: [18937] vs the predicted value: 20999.0
# The difference is: [-2062.]
#
# Original value: [18000] vs the predicted value: 21745.0
# The difference is: [-3745.]
#
# Original value: [125000] vs the predicted value: 137747.5
# The difference is: [-12747.5]
#
# Original value: [13250] vs the predicted value: 12875.5
# The difference is: [374.5]
#
# Original value: [16992] vs the predicted value: 17343.0
# The difference is: [-351.]
#
# Original value: [29990] vs the predicted value: 31242.5
# The difference is: [-1252.5]
#
# Original value: [9790] vs the predicted value: 11495.0
# The difference is: [-1705.]
#
# Original value: [11295] vs the predicted value: 10745.0
# The difference is: [550.]
#
# Original value: [17698] vs the predicted value: 16998.0
# The difference is: [700.]
#
# Original value: [29990] vs the predicted value: 25418.571428571428
# The difference is: [4571.42857143]
#
# Original value: [25499] vs the predicted value: 25490.0
# The difference is: [9.]
#
# Original value: [22988] vs the predicted value: 20466.0
# The difference is: [2522.]
#
# Original value: [82995] vs the predicted value: 84747.5
# The difference is: [-1752.5]
#
# Original value: [10020] vs the predicted value: 10994.0
# The difference is: [-974.]
#
# Original value: [15600] vs the predicted value: 19498.0
# The difference is: [-3898.]
#
# Original value: [20310] vs the predicted value: 20498.0
# The difference is: [-188.]
#
# Original value: [13498] vs the predicted value: 15395.0
# The difference is: [-1897.]
#
# Original value: [13450] vs the predicted value: 15220.5
# The difference is: [-1770.5]
#
# Original value: [8298] vs the predicted value: 8974.0
# The difference is: [-676.]
#
# Original value: [18991] vs the predicted value: 20112.0
# The difference is: [-1121.]
#
# Original value: [21998] vs the predicted value: 22500.0
# The difference is: [-502.]
#
# Original value: [22500] vs the predicted value: 24495.0
# The difference is: [-1995.]
#
# Original value: [56990] vs the predicted value: 55823.333333333336
# The difference is: [1166.66666667]
#
# Original value: [31000] vs the predicted value: 26122.5
# The difference is: [4877.5]
#
# Original value: [13000] vs the predicted value: 11990.0
# The difference is: [1010.]
#
# Original value: [10291] vs the predicted value: 11496.5
# The difference is: [-1205.5]
#
# Original value: [19991] vs the predicted value: 19990.5
# The difference is: [0.5]
#
# Original value: [17585] vs the predicted value: 16499.0
# The difference is: [1086.]
#
# Original value: [10582] vs the predicted value: 9750.0
# The difference is: [832.]
#
# Original value: [19000] vs the predicted value: 20492.5
# The difference is: [-1492.5]
#
# Original value: [16388] vs the predicted value: 16600.0
# The difference is: [-212.]
#
# Original value: [15500] vs the predicted value: 15985.0
# The difference is: [-485.]
#
# Original value: [20995] vs the predicted value: 22230.0
# The difference is: [-1235.]
#
# Original value: [17980] vs the predicted value: 15965.0
# The difference is: [2015.]
#
# Original value: [27870] vs the predicted value: 31012.5
# The difference is: [-3142.5]
#
# Original value: [17495] vs the predicted value: 17496.5
# The difference is: [-1.5]
#
# Original value: [25490] vs the predicted value: 35480.0
# The difference is: [-9990.]
#
# Original value: [18940] vs the predicted value: 16724.0
# The difference is: [2216.]
#
# Original value: [21995] vs the predicted value: 18962.0
# The difference is: [3033.]
#
# Original value: [34990] vs the predicted value: 38712.0
# The difference is: [-3722.]
#
# Original value: [29998] vs the predicted value: 31995.0
# The difference is: [-1997.]
#
# Original value: [16000] vs the predicted value: 16995.0
# The difference is: [-995.]
#
# Original value: [30985] vs the predicted value: 30981.0
# The difference is: [4.]
#
# Original value: [24500] vs the predicted value: 23245.5
# The difference is: [1254.5]
#
# Original value: [17444] vs the predicted value: 17843.5
# The difference is: [-399.5]
#
# Original value: [30543] vs the predicted value: 28242.5
# The difference is: [2300.5]
#
# Original value: [17000] vs the predicted value: 16998.0
# The difference is: [2.]
#
# Original value: [23500] vs the predicted value: 29329.0
# The difference is: [-5829.]
#
# Original value: [29490] vs the predicted value: 24792.5
# The difference is: [4697.5]
#
# Original value: [20505] vs the predicted value: 21242.5
# The difference is: [-737.5]
#
# Original value: [25312] vs the predicted value: 23396.5
# The difference is: [1915.5]
#
# Original value: [27990] vs the predicted value: 27990.0
# The difference is: [0.]
#
# Original value: [12100] vs the predicted value: 14145.0
# The difference is: [-2045.]
#
# Original value: [20895] vs the predicted value: 22382.5
# The difference is: [-1487.5]
#
# Original value: [13000] vs the predicted value: 13499.0
# The difference is: [-499.]
#
# Original value: [19995] vs the predicted value: 18349.0
# The difference is: [1646.]
#
# Original value: [10330] vs the predicted value: 9457.0
# The difference is: [873.]
#
# Original value: [22890] vs the predicted value: 23753.5
# The difference is: [-863.5]
#
# Original value: [49000] vs the predicted value: 34750.0
# The difference is: [14250.]
#
# Original value: [17497] vs the predicted value: 18450.0
# The difference is: [-953.]
#
# Original value: [26940] vs the predicted value: 26994.0
# The difference is: [-54.]
#
# Original value: [15800] vs the predicted value: 14999.0
# The difference is: [801.]
#
# Original value: [17990] vs the predicted value: 14178.5
# The difference is: [3811.5]
#
# Original value: [26495] vs the predicted value: 26742.5
# The difference is: [-247.5]
#
# Original value: [20498] vs the predicted value: 20775.0
# The difference is: [-277.]
#
# Original value: [30795] vs the predicted value: 34873.0
# The difference is: [-4078.]
#
# Original value: [34991] vs the predicted value: 33245.0
# The difference is: [1746.]
#
# Original value: [29444] vs the predicted value: 32745.0
# The difference is: [-3301.]
#
# Original value: [54990] vs the predicted value: 57995.0
# The difference is: [-3005.]
#
# Original value: [14298] vs the predicted value: 11500.0
# The difference is: [2798.]
#
# Original value: [16498] vs the predicted value: 18740.0
# The difference is: [-2242.]
#
# Original value: [17990] vs the predicted value: 17496.5
# The difference is: [493.5]
#
# Original value: [29490] vs the predicted value: 34750.0
# The difference is: [-5260.]
#
# Original value: [21498] vs the predicted value: 19730.5
# The difference is: [1767.5]
#
# Original value: [27490] vs the predicted value: 31000.0
# The difference is: [-3510.]
#
# Original value: [34998] vs the predicted value: 34498.0
# The difference is: [500.]
#
# Original value: [16402] vs the predicted value: 16492.5
# The difference is: [-90.5]
#
# Original value: [37504] vs the predicted value: 37495.0
# The difference is: [9.]
#
# Original value: [40780] vs the predicted value: 36312.0
# The difference is: [4468.]
#
# Original value: [41750] vs the predicted value: 38995.0
# The difference is: [2755.]
#
# Original value: [47000] vs the predicted value: 51745.0
# The difference is: [-4745.]
#
# Original value: [12498] vs the predicted value: 13495.0
# The difference is: [-997.]
#
# Original value: [31490] vs the predicted value: 29997.5
# The difference is: [1492.5]
#
# Original value: [16495] vs the predicted value: 17363.5
# The difference is: [-868.5]
#
# Original value: [16998] vs the predicted value: 13610.0
# The difference is: [3388.]
#
# Original value: [13042] vs the predicted value: 13971.0
# The difference is: [-929.]
#
# Original value: [32000] vs the predicted value: 33245.0
# The difference is: [-1245.]
#
# Original value: [24995] vs the predicted value: 22741.0
# The difference is: [2254.]
#
# Original value: [19498] vs the predicted value: 21495.0
# The difference is: [-1997.]
#
# Original value: [19840] vs the predicted value: 21995.0
# The difference is: [-2155.]
#
# Original value: [13252] vs the predicted value: 16644.5
# The difference is: [-3392.5]
#
# Original value: [30500] vs the predicted value: 34491.0
# The difference is: [-3991.]
#
# Original value: [22991] vs the predicted value: 23245.5
# The difference is: [-254.5]
#
# Original value: [19495] vs the predicted value: 19647.5
# The difference is: [-152.5]
#
# Original value: [14995] vs the predicted value: 11949.5
# The difference is: [3045.5]
#
# Original value: [14491] vs the predicted value: 13990.0
# The difference is: [501.]
#
# Original value: [21251] vs the predicted value: 19870.5
# The difference is: [1380.5]
#
# Original value: [32500] vs the predicted value: 32890.0
# The difference is: [-390.]
#
# Original value: [21790] vs the predicted value: 21490.0
# The difference is: [300.]
#
# Original value: [22190] vs the predicted value: 22442.5
# The difference is: [-252.5]
#
# Original value: [35498] vs the predicted value: 34498.0
# The difference is: [1000.]
#
# Original value: [17698] vs the predicted value: 16793.5
# The difference is: [904.5]
#
# Original value: [13900] vs the predicted value: 10985.0
# The difference is: [2915.]
#
# Original value: [6800] vs the predicted value: 8995.0
# The difference is: [-2195.]
#
# Original value: [18000] vs the predicted value: 17500.0
# The difference is: [500.]
#
# Original value: [10995] vs the predicted value: 10745.0
# The difference is: [250.]
#
# Original value: [33495] vs the predicted value: 36819.5
# The difference is: [-3324.5]
#
# Original value: [31000] vs the predicted value: 36443.0
# The difference is: [-5443.]
#
# Original value: [15749] vs the predicted value: 12495.0
# The difference is: [3254.]
#
# Original value: [23500] vs the predicted value: 22841.0
# The difference is: [659.]
#
# Original value: [22490] vs the predicted value: 16436.0
# The difference is: [6054.]
#
# Original value: [23450] vs the predicted value: 21691.0
# The difference is: [1759.]
#
# Original value: [26000] vs the predicted value: 24258.5
# The difference is: [1741.5]
#
# Original value: [15290] vs the predicted value: 15485.0
# The difference is: [-195.]
#
# Original value: [15700] vs the predicted value: 15400.0
# The difference is: [300.]
#
# Original value: [55900] vs the predicted value: 53472.5
# The difference is: [2427.5]
#
# Original value: [14298] vs the predicted value: 15998.0
# The difference is: [-1700.]
#
# Original value: [17695] vs the predicted value: 19350.0
# The difference is: [-1655.]
#
# Original value: [23499] vs the predicted value: 24644.0
# The difference is: [-1145.]

# %% [markdown]
# # User Input Predictions

# %%
inputPred = []
entries = []

def userInput():
    chooseBrand = input("Choose your car brand: Audi, BMW, Ford, Hyundai, Mercedes, Skoda, Toyota, Vauxhall or Volkswagen \n")
    
    if chooseBrand == "Audi":
        return "UKUsedCarDataSet/audi.csv"
    elif chooseBrand == "BMW":
        return "UKUsedCarDataSet/bmw.csv"
    elif chooseBrand == "Ford":
        return "UKUsedCarDataSet/ford.csv"
    elif chooseBrand == "Hyundai":
        return "UKUsedCarDataSet/hyundi.csv"
    elif chooseBrand == "Mercedes":
        return "UKUsedCarDataSet/merc.csv"
    elif chooseBrand == "Skoda":
        return "UKUsedCarDataSet/skoda.csv"
    elif chooseBrand == "Toyota":
        return "UKUsedCarDataSet/toyota.csv"
    elif chooseBrand == "Vauxhall":
        return "UKUsedCarDataSet/vauxhall.csv"
    elif chooseBrand == "Volkswagen":
        return "UKUsedCarDataSet/vw.csv"
    else:
        print("Invalid Car Brand")
        userInput()
    return 

X_train, X_test, Y_train, Y_test = dataset(userInput())
print("\n ***Training Tree Model***")
myTree = DTRegressor(3, 93)  
myTree.fit(X_train, Y_train)

print("\n List of models:")
print(list(modelEncoder.classes_))
inputPred.append((modelEncoder.transform([input("\nWhat Model is your car? ")]))[0])
inputPred.append(int(input("What year is your car? ")))
inputPred.append((transmissionEncoder.transform([input("What transmission is your car? ")]))[0])
inputPred.append(int(input("How much mileage does your car have? ")))
inputPred.append((fuelTypeEncoder.transform([input("What's your car fuel type? ")]))[0])
inputPred.append(int(input("How much is your cars tax? ")))
inputPred.append(float(input("What's MPG of your car? ")))
inputPred.append(float(input("What the engine size of your car? ")))
entries.append(inputPred)
# inputPred = scaler.transform([inputPred])

import time
print("\n ***Predicting***")
start = time.time()
y_pred = myTree.predict([inputPred])
# {0:.2f}'.format()
print("\n Predicted price for your car is: £", y_pred[0])

print("\n ***Predicted in", time.time() - start,"seconds***")

# RS6,2016,Semi-Auto,49050,Petrol,325,29.4,4.0 -- Price is £44,985   old Pred = £41,233.30,  new pred = £45492.50
# BMW,5 Series,2019,Semi-Auto,4405,Petrol,145,48.7,2.0     Price = £26,000 old Pred = £27,077.49, new pred = £26500.00
# Out:
# Choose your car brand: Audi, BMW, Ford, Hyundai, Mercedes, Skoda, Toyota, Vauxhall or Volkswagen
# Audi
#
#  ***Training Tree Model***
#
#  List of models:
# ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'Q2', 'Q3', 'Q5', 'Q7', 'Q8', 'R8', 'RS3', 'RS4', 'RS5', 'RS6', 'RS7', 'S3', 'S4', 'S5', 'S8', 'SQ5', 'SQ7', 'TT']
#
# What Model is your car? RS6
# What year is your car? 2016
# What transmission is your car? Semi-Auto
# How much mileage does your car have? 49050
# What's your car fuel type? Petrol
# How much is your cars tax? 325
# What's MPG of your car? 29.4
# What the engine size of your car? 4
#
#  ***Predicting***
#
#  Predicted price for your car is: £ 45492.5
#
#  ***Predicted in 0.0007822513580322266 seconds***
