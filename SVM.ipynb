# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import csv
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
from sklearn.metrics import mean_squared_error 
from sklearn.preprocessing import LabelEncoder
# import cvxopt

# %%
# class SVMRegression:
#     def __init__(self, C=1, kernel='linear', degree=3, gamma='scale'):
#         self.C = C
#         self.kernel = kernel
#         self.degree = degree
#         self.gamma = gamma
#         self.support_vectors_ = None
#         self.support_vectors_y_ = None

#     def fit(self, X, y):
#         n_samples, n_features = X.shape

#         # Compute the kernel matrix
#         K = np.zeros((n_samples, n_samples))
#         for i in range(n_samples):
#             for j in range(n_samples):
#                 K[i,j] = self.kernel_function(X[i], X[j])

#         # # Define the quadrbatic programming problem
#         # P = np.outer(y, y) * K
#         # q = -np.ones(n_samples)
#         # G = np.vstack((np.eye(n_samples)*-1, np.eye(n_samples)))
#         # h = np.hstack((np.zeros(n_samples), np.ones(n_samples) * self.C))

#         # # Solve the quadratic programming problem using an optimizer
        
#         # P, q, G, h = matrix(P), matrix(q), matrix(G), matrix(h)
#         # solvers.options['show_progress'] = False
#         # solution = solvers.qp(P, q, G, h)

#         # # Get the Lagrange multipliers
#         # lagrange_multipliers = np.array(solution['x']).flatten()


#      # Initialize Lagrange multipliers and error cache
#         lagrange_multipliers = np.zeros(n_samples)
#         error_cache = np.zeros(n_samples)

#         # Train the SVM regression model using SMO algorithm
#         num_changed = 0
#         examine_all = True
#         iteration = 0
#         while num_changed > 0 or examine_all:
#             num_changed = 0
#             if examine_all:
#                 for i in range(n_samples):
#                     num_changed += self.examine_example(i, X, y, K, lagrange_multipliers, error_cache)
#             else:
#                 non_bound_indices = np.where((lagrange_multipliers > 0) & (lagrange_multipliers < self.C))[0]
#                 for i in non_bound_indices:
#                     num_changed += self.examine_example(i, X, y, K, lagrange_multipliers, error_cache)
#             if examine_all:
#                 examine_all = False
#             elif num_changed == 0:
#                 examine_all = True
#             iteration += 1
#             if iteration >= self.max_iter:
#                 break



#         # Select the support vectors
#         threshold = 1e-5
#         support_vectors = lagrange_multipliers > threshold
#         self.support_vectors_ = X[support_vectors]
#         self.support_vectors_y_ = y[support_vectors]
#         self.lagrange_multipliers_ = lagrange_multipliers[support_vectors]

#         # Compute the bias term
#         self.intercept_ = np.mean(self.support_vectors_y_ - np.sum(self.lagrange_multipliers_ * self.support_vectors_y_ * K[support_vectors, :], axis=0))

#     def kernel_function(self, x1, x2):
#         if self.kernel == 'linear':
#             return np.dot(x1, x2)
#         elif self.kernel == 'poly':
#             return (np.dot(x1, x2) + 1) ** self.degree
#         elif self.kernel == 'rbf':
#             return np.exp(-self.gamma * np.linalg.norm(x1 - x2) ** 2)
        



#     def examine_example(self, i, X, y, K, lagrange_multipliers, error_cache):
#         y_i = y[i]
#         alpha_i = lagrange_multipliers[i]
#         E_i = self.predict(X[i]) - y_i
#         r_i = E_i * y_i

#         if ((r_i < -self.tol and alpha_i < self.C) or (r_i > self.tol and alpha_i > 0)):
#             non_bound_indices = np.where((lagrange_multipliers > 0) & (lagrange_multipliers < self.C))[0]
#             if len(non_bound_indices) > 1:
#                 j = self.select_second_example(i, E_i, error_cache)
#                 if self.take_step

#     def predict(self, X):
#         n_samples, n_features = X.shape

#         # Compute the kernel matrix
#         K = np.zeros((n_samples, len(self.support_vectors_)))
#         for i in range(n_samples):
#             for j in range(len(self.support_vectors_)):
#                 K[i,j] = self.kernel_function(X[i], self.support_vectors_[j])

#         # Make predictions
#         y_pred = np.sum(self.lagrange_multipliers_ * self.support_vectors_y_ * K, axis=1) + self.intercept_

#         return y_pred

# %%
import numpy as np

class SVMRegression:
    def __init__(self, C=1, learning_rate=0.01, num_iterations=1000):
        self.C = C
        self.learning_rate = learning_rate
        self.num_iterations = num_iterations
        self.weights = None
        self.bias = None
        
    def fit(self, X, y):
        # Convert labels to -1/+1
        y = np.where(y == 0, -1, 1)
        
        # Initialize weights and bias to zero
        self.weights = np.zeros(X.shape[1])
        self.bias = 0
        
        # Gradient descent optimization
        for iteration in range(self.num_iterations):
            # Compute gradients
            grad_weights = np.zeros(X.shape[1])
            grad_bias = 0
            for i in range(X.shape[0]):
                if y[i] * (np.dot(self.weights, X[i]) + self.bias) < 1:
                    grad_weights += self.C * y[i] * X[i]
                    grad_bias += self.C * y[i]
                else:
                    grad_weights += 0
                    grad_bias += 0
                    
            # Update weights and bias
            self.weights -= self.learning_rate * grad_weights
            self.bias -= self.learning_rate * grad_bias
            
    def predict(self, X):
        return np.dot(X, self.weights) + self.bias

# %%
modelEncoder = LabelEncoder()
transmissionEncoder = LabelEncoder()
fuelTypeEncoder = LabelEncoder()
scaler = MinMaxScaler()

def dataset(brand):
    file = pd.read_csv(brand, quotechar='"', skipinitialspace=True)

    modelEncoder.fit(file["model"])
    file["model"] = modelEncoder.transform(file["model"])
    
    transmissionEncoder.fit(file["transmission"])
    file["transmission"] = transmissionEncoder.transform(file["transmission"])
    
    fuelTypeEncoder.fit(file["fuelType"])
    file["fuelType"] = fuelTypeEncoder.transform(file["fuelType"])

    file = file.head(1000) # Limits dataset size

    X = file.drop(columns = ['price'])
    Y = file.price

#     print(file)
    
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 601)
    
    scaler.fit(X_train)

    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    
    print(list(fuelTypeEncoder.classes_))

    return  X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = dataset("UKUsedCarDataSet/audi.csv") # Use Audi dataset as default for KNN analysis
# Out:
# ['Diesel', 'Hybrid', 'Petrol']

# %%
def rmse(test, pred):
    print("RMSE: ")
    MSE = np.square(np.subtract(test, pred)).mean()
    return sqrt(MSE)

# %%
SVM = SVMRegression()
SVM.fit( X_train, Y_train )
Y_pred = SVM.predict( X_test )

# %%
def evaluation(train, test, yTrain, yTest):    
    y_pred =  SVM.predict(X_test)
    error = rmse(yTest, y_pred) 
    print('The RMSE value is:', error)
    for i in range(len(y_pred)):
        print("\nOriginal value:", yTest.iloc[i], "vs the predicted value:", y_pred[i])
        print("The difference is:", yTest.iloc[i] - y_pred[i])
evaluation(X_train, X_test, Y_train, Y_test)
# Out:
# RMSE:
# The RMSE value is: 41432.4123298029
#
# Original value: 18498 vs the predicted value: -15213.45362901096
# The difference is: 33711.45362901096
#
# Original value: 22995 vs the predicted value: -16812.60810046879
# The difference is: 39807.60810046879
#
# Original value: 12495 vs the predicted value: -12513.519925095863
# The difference is: 25008.51992509586
#
# Original value: 14500 vs the predicted value: -16661.421392841225
# The difference is: 31161.421392841225
#
# Original value: 24995 vs the predicted value: -18279.92401780009
# The difference is: 43274.92401780009
#
# Original value: 10200 vs the predicted value: -14821.72780543368
# The difference is: 25021.72780543368
#
# Original value: 21995 vs the predicted value: -18141.727625701657
# The difference is: 40136.72762570166
#
# Original value: 16800 vs the predicted value: -12587.097969313607
# The difference is: 29387.097969313607
#
# Original value: 12798 vs the predicted value: -17247.852313164018
# The difference is: 30045.852313164018
#
# Original value: 20498 vs the predicted value: -16389.720590390076
# The difference is: 36887.720590390076
#
# Original value: 11498 vs the predicted value: -18137.424866728245
# The difference is: 29635.424866728245
#
# Original value: 48136 vs the predicted value: -18433.379137695032
# The difference is: 66569.37913769504
#
# Original value: 32485 vs the predicted value: -13048.14322206176
# The difference is: 45533.14322206176
#
# Original value: 17490 vs the predicted value: -14721.898496344873
# The difference is: 32211.898496344875
#
# Original value: 33985 vs the predicted value: -13273.453431976395
# The difference is: 47258.45343197639
#
# Original value: 36888 vs the predicted value: -17737.82114445618
# The difference is: 54625.821144456175
#
# Original value: 31995 vs the predicted value: -17620.244521117125
# The difference is: 49615.24452111713
#
# Original value: 23374 vs the predicted value: -15246.092754384441
# The difference is: 38620.092754384445
#
# Original value: 19498 vs the predicted value: -13924.461211882302
# The difference is: 33422.4612118823
#
# Original value: 13450 vs the predicted value: -15238.090117028578
# The difference is: 28688.09011702858
#
# Original value: 23995 vs the predicted value: -13122.968445213228
# The difference is: 37117.96844521323
#
# Original value: 23998 vs the predicted value: -20505.704643367993
# The difference is: 44503.70464336799
#
# Original value: 21995 vs the predicted value: -16360.607565396353
# The difference is: 38355.60756539635
#
# Original value: 37985 vs the predicted value: -13353.96736725609
# The difference is: 51338.96736725609
#
# Original value: 18995 vs the predicted value: -20037.875989149223
# The difference is: 39032.87598914922
#
# Original value: 30709 vs the predicted value: -20900.165057477298
# The difference is: 51609.165057477294
#
# Original value: 22998 vs the predicted value: -20169.876172650278
# The difference is: 43167.87617265028
#
# Original value: 17300 vs the predicted value: -12620.595859436517
# The difference is: 29920.595859436515
#
# Original value: 31985 vs the predicted value: -15468.398712460556
# The difference is: 47453.398712460556
#
# Original value: 14900 vs the predicted value: -12841.559132007795
# The difference is: 27741.559132007795
#
# Original value: 13995 vs the predicted value: -16061.954395275538
# The difference is: 30056.954395275538
#
# Original value: 10995 vs the predicted value: -15510.152011253307
# The difference is: 26505.152011253307
#
# Original value: 13500 vs the predicted value: -16349.161446537692
# The difference is: 29849.16144653769
#
# Original value: 12995 vs the predicted value: -15734.465106580017
# The difference is: 28729.465106580017
#
# Original value: 19995 vs the predicted value: -17035.024766339946
# The difference is: 37030.02476633995
#
# Original value: 33640 vs the predicted value: -17577.64052187609
# The difference is: 51217.64052187609
#
# Original value: 19998 vs the predicted value: -17755.46899450991
# The difference is: 37753.46899450991
#
# Original value: 14995 vs the predicted value: -17342.02702566083
# The difference is: 32337.02702566083
#
# Original value: 11698 vs the predicted value: -15925.571003523488
# The difference is: 27623.571003523488
#
# Original value: 24495 vs the predicted value: -15177.970660928066
# The difference is: 39672.97066092807
#
# Original value: 28062 vs the predicted value: -18606.72746814113
# The difference is: 46668.72746814113
#
# Original value: 11000 vs the predicted value: -17378.657538486557
# The difference is: 28378.657538486557
#
# Original value: 11500 vs the predicted value: -14128.49863065465
# The difference is: 25628.49863065465
#
# Original value: 12000 vs the predicted value: -12198.732998545987
# The difference is: 24198.732998545987
#
# Original value: 45995 vs the predicted value: -18162.784235382795
# The difference is: 64157.784235382795
#
# Original value: 14495 vs the predicted value: -16953.961909718135
# The difference is: 31448.961909718135
#
# Original value: 24998 vs the predicted value: -20954.352475369124
# The difference is: 45952.35247536912
#
# Original value: 18498 vs the predicted value: -15787.742877782073
# The difference is: 34285.742877782075
#
# Original value: 7898 vs the predicted value: -15473.090016350267
# The difference is: 23371.090016350267
#
# Original value: 18295 vs the predicted value: -16136.8545908424
# The difference is: 34431.8545908424
#
# Original value: 16798 vs the predicted value: -16168.988687364224
# The difference is: 32966.988687364224
#
# Original value: 21100 vs the predicted value: -12589.016989050113
# The difference is: 33689.01698905011
#
# Original value: 12990 vs the predicted value: -16414.429705453833
# The difference is: 29404.429705453833
#
# Original value: 11950 vs the predicted value: -12879.089146681392
# The difference is: 24829.089146681392
#
# Original value: 16485 vs the predicted value: -16632.33684692603
# The difference is: 33117.33684692603
#
# Original value: 22495 vs the predicted value: -15246.092754384441
# The difference is: 37741.092754384445
#
# Original value: 16000 vs the predicted value: -19818.557560179746
# The difference is: 35818.557560179746
#
# Original value: 16995 vs the predicted value: -15346.271022434667
# The difference is: 32341.271022434667
#
# Original value: 19995 vs the predicted value: -16745.90049012313
# The difference is: 36740.90049012313
#
# Original value: 24500 vs the predicted value: -17806.94081744744
# The difference is: 42306.94081744744
#
# Original value: 13985 vs the predicted value: -14124.052405819433
# The difference is: 28109.052405819435
#
# Original value: 20888 vs the predicted value: -18455.78557452279
# The difference is: 39343.785574522786
#
# Original value: 19995 vs the predicted value: -17782.79399655115
# The difference is: 37777.79399655115
#
# Original value: 38995 vs the predicted value: -13252.566287904989
# The difference is: 52247.56628790499
#
# Original value: 36995 vs the predicted value: -13446.577371071402
# The difference is: 50441.5773710714
#
# Original value: 21995 vs the predicted value: -19877.466909834842
# The difference is: 41872.46690983484
#
# Original value: 15998 vs the predicted value: -15954.079904342107
# The difference is: 31952.079904342107
#
# Original value: 11500 vs the predicted value: -11562.430638037991
# The difference is: 23062.430638037993
#
# Original value: 18998 vs the predicted value: -16465.34684537162
# The difference is: 35463.34684537162
#
# Original value: 14100 vs the predicted value: -16262.796155492084
# The difference is: 30362.796155492084
#
# Original value: 16390 vs the predicted value: -16084.781520996285
# The difference is: 32474.781520996286
#
# Original value: 19990 vs the predicted value: -12515.314007397832
# The difference is: 32505.314007397832
#
# Original value: 11650 vs the predicted value: -16047.947911651208
# The difference is: 27697.94791165121
#
# Original value: 18990 vs the predicted value: -20590.707058878226
# The difference is: 39580.70705887822
#
# Original value: 33490 vs the predicted value: -18121.714746896236
# The difference is: 51611.714746896236
#
# Original value: 18995 vs the predicted value: -19265.834533573237
# The difference is: 38260.83453357324
#
# Original value: 15600 vs the predicted value: -17976.886362250654
# The difference is: 33576.886362250654
#
# Original value: 11995 vs the predicted value: -11855.780043033474
# The difference is: 23850.780043033476
#
# Original value: 37995 vs the predicted value: -17728.611956204557
# The difference is: 55723.61195620456
#
# Original value: 16000 vs the predicted value: -16200.108170983727
# The difference is: 32200.108170983727
#
# Original value: 30995 vs the predicted value: -20852.106246281095
# The difference is: 51847.106246281095
#
# Original value: 49995 vs the predicted value: -18712.32314197847
# The difference is: 68707.32314197847
#
# Original value: 25990 vs the predicted value: -18601.381787497754
# The difference is: 44591.381787497754
#
# Original value: 23985 vs the predicted value: -20525.512240916116
# The difference is: 44510.51224091611
#
# Original value: 17395 vs the predicted value: -14264.563739226483
# The difference is: 31659.563739226483
#
# Original value: 16498 vs the predicted value: -13333.71788817149
# The difference is: 29831.71788817149
#
# Original value: 24365 vs the predicted value: -15264.980196402257
# The difference is: 39629.980196402255
#
# Original value: 29985 vs the predicted value: -16005.506890557253
# The difference is: 45990.506890557255
#
# Original value: 14995 vs the predicted value: -17812.58088060269
# The difference is: 32807.58088060269
#
# Original value: 22945 vs the predicted value: -17153.252743477948
# The difference is: 40098.25274347795
#
# Original value: 47995 vs the predicted value: -17851.280185524018
# The difference is: 65846.28018552403
#
# Original value: 19995 vs the predicted value: -19216.82521723218
# The difference is: 39211.82521723218
#
# Original value: 21450 vs the predicted value: -12756.420594511896
# The difference is: 34206.420594511896
#
# Original value: 11998 vs the predicted value: -15061.563281624818
# The difference is: 27059.563281624818
#
# Original value: 23995 vs the predicted value: -20313.054319192794
# The difference is: 44308.05431919279
#
# Original value: 10200 vs the predicted value: -16218.669076629587
# The difference is: 26418.669076629587
#
# Original value: 30995 vs the predicted value: -20728.607242185346
# The difference is: 51723.607242185346
#
# Original value: 49995 vs the predicted value: -14238.787859953474
# The difference is: 64233.787859953474
#
# Original value: 12450 vs the predicted value: -12821.574899889309
# The difference is: 25271.57489988931
#
# Original value: 23995 vs the predicted value: -15337.750083553032
# The difference is: 39332.75008355303
#
# Original value: 16995 vs the predicted value: -16545.341610482163
# The difference is: 33540.341610482166
#
# Original value: 34485 vs the predicted value: -13314.610967261171
# The difference is: 47799.61096726117
#
# Original value: 19995 vs the predicted value: -18313.142741336225
# The difference is: 38308.142741336225
#
# Original value: 25998 vs the predicted value: -17667.80363591865
# The difference is: 43665.80363591865
#
# Original value: 21500 vs the predicted value: -17307.979987361054
# The difference is: 38807.979987361054
#
# Original value: 21288 vs the predicted value: -14966.046274908558
# The difference is: 36254.04627490856
#
# Original value: 12495 vs the predicted value: -16935.389740497514
# The difference is: 29430.389740497514
#
# Original value: 36995 vs the predicted value: -17752.228259289026
# The difference is: 54747.228259289026
#
# Original value: 51995 vs the predicted value: -18751.908167272406
# The difference is: 70746.9081672724
#
# Original value: 14998 vs the predicted value: -16119.610827449173
# The difference is: 31117.61082744917
#
# Original value: 20495 vs the predicted value: -16334.262156701074
# The difference is: 36829.26215670107
#
# Original value: 22995 vs the predicted value: -16137.681448447256
# The difference is: 39132.681448447256
#
# Original value: 25000 vs the predicted value: -16678.3435126848
# The difference is: 41678.343512684805
#
# Original value: 11300 vs the predicted value: -13727.284357884568
# The difference is: 25027.284357884568
#
# Original value: 20890 vs the predicted value: -18166.02918598815
# The difference is: 39056.029185988154
#
# Original value: 20498 vs the predicted value: -18147.92836770048
# The difference is: 38645.92836770048
#
# Original value: 36497 vs the predicted value: -13331.157421651562
# The difference is: 49828.15742165156
#
# Original value: 16900 vs the predicted value: -17210.42854093336
# The difference is: 34110.42854093336
#
# Original value: 42500 vs the predicted value: -13738.10154325688
# The difference is: 56238.10154325688
#
# Original value: 33444 vs the predicted value: -21756.941982857086
# The difference is: 55200.94198285708
#
# Original value: 27022 vs the predicted value: -20890.806047129045
# The difference is: 47912.806047129045
#
# Original value: 14998 vs the predicted value: -13270.943007822261
# The difference is: 28268.94300782226
#
# Original value: 37507 vs the predicted value: -21595.52046852889
# The difference is: 59102.52046852889
#
# Original value: 18300 vs the predicted value: -18252.67732839629
# The difference is: 36552.67732839629
#
# Original value: 14495 vs the predicted value: -13890.936435980195
# The difference is: 28385.936435980195
#
# Original value: 27990 vs the predicted value: -17471.939751941354
# The difference is: 45461.939751941354
#
# Original value: 37888 vs the predicted value: -21708.65293464928
# The difference is: 59596.652934649275
#
# Original value: 47995 vs the predicted value: -18415.92475191786
# The difference is: 66410.92475191786
#
# Original value: 17100 vs the predicted value: -16907.211354236722
# The difference is: 34007.21135423672
#
# Original value: 22663 vs the predicted value: -15290.500763793803
# The difference is: 37953.5007637938
#
# Original value: 21498 vs the predicted value: -16687.979816892377
# The difference is: 38185.97981689237
#
# Original value: 13688 vs the predicted value: -16355.913021354529
# The difference is: 30043.91302135453
#
# Original value: 9998 vs the predicted value: -17250.46880590059
# The difference is: 27248.46880590059
#
# Original value: 33444 vs the predicted value: -21707.770600214128
# The difference is: 55151.77060021413
#
# Original value: 41888 vs the predicted value: -18031.842347185284
# The difference is: 59919.84234718529
#
# Original value: 17200 vs the predicted value: -12146.24151696787
# The difference is: 29346.24151696787
#
# Original value: 28995 vs the predicted value: -17417.91794889928
# The difference is: 46412.91794889928
#
# Original value: 49990 vs the predicted value: -18359.09877137874
# The difference is: 68349.09877137875
#
# Original value: 28000 vs the predicted value: -15535.08593773092
# The difference is: 43535.085937730924
#
# Original value: 20088 vs the predicted value: -17653.148394734173
# The difference is: 37741.14839473418
#
# Original value: 20350 vs the predicted value: -18140.098584464362
# The difference is: 38490.09858446436
#
# Original value: 42995 vs the predicted value: -13740.251013108093
# The difference is: 56735.25101310809
#
# Original value: 32494 vs the predicted value: -13139.289013227884
# The difference is: 45633.289013227884
#
# Original value: 16200 vs the predicted value: -11361.229836746132
# The difference is: 27561.229836746134
#
# Original value: 11300 vs the predicted value: -13281.259157866274
# The difference is: 24581.259157866276
#
# Original value: 23995 vs the predicted value: -17137.53334290388
# The difference is: 41132.53334290388
#
# Original value: 11495 vs the predicted value: -15865.769777453972
# The difference is: 27360.76977745397
#
# Original value: 10000 vs the predicted value: -15353.882615066857
# The difference is: 25353.882615066857
#
# Original value: 19995 vs the predicted value: -19362.66252600417
# The difference is: 39357.66252600417
#
# Original value: 18995 vs the predicted value: -14133.68885705668
# The difference is: 33128.68885705668
#
# Original value: 23995 vs the predicted value: -13088.103895861352
# The difference is: 37083.10389586135
#
# Original value: 28995 vs the predicted value: -17466.6319141051
# The difference is: 46461.6319141051
#
# Original value: 16998 vs the predicted value: -17155.33309085543
# The difference is: 34153.333090855434
#
# Original value: 19485 vs the predicted value: -15027.219123980154
# The difference is: 34512.219123980154
#
# Original value: 22698 vs the predicted value: -18712.1987643495
# The difference is: 41410.1987643495
#
# Original value: 33995 vs the predicted value: -17804.687648383016
# The difference is: 51799.68764838301
#
# Original value: 21495 vs the predicted value: -17469.43089214161
# The difference is: 38964.43089214161
#
# Original value: 23995 vs the predicted value: -20337.60658333369
# The difference is: 44332.60658333369
#
# Original value: 17950 vs the predicted value: -17797.758138302554
# The difference is: 35747.75813830255
#
# Original value: 22995 vs the predicted value: -14587.065557875518
# The difference is: 37582.06555787552
#
# Original value: 27498 vs the predicted value: -20485.94170964682
# The difference is: 47983.941709646824
#
# Original value: 19498 vs the predicted value: -16913.371196358377
# The difference is: 36411.37119635838
#
# Original value: 17695 vs the predicted value: -14067.570978842647
# The difference is: 31762.570978842647
#
# Original value: 21285 vs the predicted value: -14861.954034561732
# The difference is: 36146.95403456173
#
# Original value: 15700 vs the predicted value: -11957.302471505282
# The difference is: 27657.30247150528
#
# Original value: 25499 vs the predicted value: -17822.283380379107
# The difference is: 43321.28338037911
#
# Original value: 17998 vs the predicted value: -16621.366426865185
# The difference is: 34619.366426865185
#
# Original value: 17998 vs the predicted value: -12956.510233633946
# The difference is: 30954.510233633948
#
# Original value: 16498 vs the predicted value: -17902.807722226575
# The difference is: 34400.80772222657
#
# Original value: 13995 vs the predicted value: -17351.204815086574
# The difference is: 31346.204815086574
#
# Original value: 60995 vs the predicted value: -14108.708051934342
# The difference is: 75103.70805193434
#
# Original value: 17500 vs the predicted value: -12637.13957796097
# The difference is: 30137.13957796097
#
# Original value: 15998 vs the predicted value: -16229.739484798984
# The difference is: 32227.739484798985
#
# Original value: 29000 vs the predicted value: -20944.22268170651
# The difference is: 49944.22268170651
#
# Original value: 25000 vs the predicted value: -18615.218354842247
# The difference is: 43615.21835484225
#
# Original value: 31998 vs the predicted value: -21127.27479476616
# The difference is: 53125.274794766156
#
# Original value: 16100 vs the predicted value: -17552.43587255074
# The difference is: 33652.43587255074
#
# Original value: 39454 vs the predicted value: -18167.865922293146
# The difference is: 57621.865922293146
#
# Original value: 17298 vs the predicted value: -17645.85699290107
# The difference is: 34943.85699290107
#
# Original value: 25995 vs the predicted value: -17154.002270737168
# The difference is: 43149.00227073717
#
# Original value: 16100 vs the predicted value: -13744.05682644614
# The difference is: 29844.05682644614
#
# Original value: 21995 vs the predicted value: -17523.923273611086
# The difference is: 39518.923273611086
#
# Original value: 15200 vs the predicted value: -15497.579806315753
# The difference is: 30697.579806315753
#
# Original value: 14500 vs the predicted value: -15909.912983640541
# The difference is: 30409.91298364054
#
# Original value: 28985 vs the predicted value: -20763.765119835967
# The difference is: 49748.76511983597
#
# Original value: 17998 vs the predicted value: -14060.208992244683
# The difference is: 32058.208992244683
#
# Original value: 15000 vs the predicted value: -17288.506978312642
# The difference is: 32288.506978312642
#
# Original value: 19500 vs the predicted value: -11750.046281606907
# The difference is: 31250.046281606905
#
# Original value: 34995 vs the predicted value: -13156.699287815114
# The difference is: 48151.699287815114
#
# Original value: 26495 vs the predicted value: -15636.54851059742
# The difference is: 42131.54851059742
#
# Original value: 34259 vs the predicted value: -18652.498529911365
# The difference is: 52911.49852991136
#
# Original value: 16995 vs the predicted value: -14067.582776051402
# The difference is: 31062.5827760514
#
# Original value: 25995 vs the predicted value: -18662.816374579263
# The difference is: 44657.81637457926
#
# Original value: 20000 vs the predicted value: -12678.744452526867
# The difference is: 32678.744452526866
#
# Original value: 20200 vs the predicted value: -15528.252709995792
# The difference is: 35728.252709995795
#
# Original value: 16998 vs the predicted value: -15957.217072785845
# The difference is: 32955.21707278585
#
# Original value: 12698 vs the predicted value: -13297.424769904988
# The difference is: 25995.42476990499
#
# Original value: 15995 vs the predicted value: -17784.974558629772
# The difference is: 33779.97455862977
#
# Original value: 12798 vs the predicted value: -16425.591979287397
# The difference is: 29223.591979287397
#
# Original value: 26990 vs the predicted value: -20423.56017841168
# The difference is: 47413.56017841168
#
# Original value: 18990 vs the predicted value: -15672.307150346456
# The difference is: 34662.30715034646
#
# Original value: 22988 vs the predicted value: -20173.86268075875
# The difference is: 43161.86268075875
#
# Original value: 18990 vs the predicted value: -16873.84975749865
# The difference is: 35863.849757498654
#
# Original value: 13998 vs the predicted value: -13815.001817522761
# The difference is: 27813.00181752276
#
# Original value: 35131 vs the predicted value: -18671.451741303994
# The difference is: 53802.451741303994
#
# Original value: 22490 vs the predicted value: -18561.197745595848
# The difference is: 41051.19774559585
#
# Original value: 35895 vs the predicted value: -13097.115338419411
# The difference is: 48992.11533841941
#
# Original value: 33298 vs the predicted value: -17575.568036679717
# The difference is: 50873.56803667972
#
# Original value: 35995 vs the predicted value: -13371.834195279655
# The difference is: 49366.834195279655
#
# Original value: 16000 vs the predicted value: -13917.84891299767
# The difference is: 29917.84891299767
#
# Original value: 36995 vs the predicted value: -13120.111710973502
# The difference is: 50115.111710973506
#
# Original value: 36998 vs the predicted value: -21102.23487355407
# The difference is: 58100.23487355407
#
# Original value: 25990 vs the predicted value: -20839.596964415156
# The difference is: 46829.596964415156
#
# Original value: 30543 vs the predicted value: -21264.73220513371
# The difference is: 51807.73220513371
#
# Original value: 24995 vs the predicted value: -20933.02570067325
# The difference is: 45928.02570067325
#
# Original value: 15000 vs the predicted value: -10952.487851490274
# The difference is: 25952.487851490274
#
# Original value: 14300 vs the predicted value: -13953.373221744003
# The difference is: 28253.373221744005
#
# Original value: 13498 vs the predicted value: -16594.17651023783
# The difference is: 30092.17651023783
#
# Original value: 30995 vs the predicted value: -17543.444516135947
# The difference is: 48538.44451613595
#
# Original value: 19995 vs the predicted value: -14983.913102932122
# The difference is: 34978.91310293212
#
# Original value: 19995 vs the predicted value: -14061.54375793347
# The difference is: 34056.54375793347
#
# Original value: 35998 vs the predicted value: -21111.91669048896
# The difference is: 57109.91669048896
#
# Original value: 21490 vs the predicted value: -17816.87195789175
# The difference is: 39306.87195789175
#
# Original value: 25995 vs the predicted value: -17596.43613695912
# The difference is: 43591.43613695912
#
# Original value: 11600 vs the predicted value: -12530.391499931886
# The difference is: 24130.391499931888
#
# Original value: 18950 vs the predicted value: -16826.701926842547
# The difference is: 35776.70192684255
#
# Original value: 19495 vs the predicted value: -16416.451695486103
# The difference is: 35911.4516954861
#
# Original value: 59995 vs the predicted value: -22169.013026652166
# The difference is: 82164.01302665216
#
# Original value: 9998 vs the predicted value: -16107.01103421822
# The difference is: 26105.01103421822
#
# Original value: 15600 vs the predicted value: -18015.517929379792
# The difference is: 33615.51792937979
#
# Original value: 19995 vs the predicted value: -18131.214777407156
# The difference is: 38126.214777407156
#
# Original value: 31000 vs the predicted value: -12713.599668269788
# The difference is: 43713.59966826979
#
# Original value: 19800 vs the predicted value: -18439.245518520693
# The difference is: 38239.24551852069
#
# Original value: 16000 vs the predicted value: -11885.069049511167
# The difference is: 27885.069049511167
#
# Original value: 59995 vs the predicted value: -13923.103763516236
# The difference is: 73918.10376351624
#
# Original value: 36990 vs the predicted value: -19520.571234930107
# The difference is: 56510.5712349301
#
# Original value: 27985 vs the predicted value: -20861.52519488
# The difference is: 48846.52519488
#
# Original value: 52995 vs the predicted value: -18115.04876469099
# The difference is: 71110.04876469099
#
# Original value: 22285 vs the predicted value: -12132.482354783931
# The difference is: 34417.48235478393
#
# Original value: 30995 vs the predicted value: -17373.553329545564
# The difference is: 48368.55332954557
#
# Original value: 14500 vs the predicted value: -15290.654533319748
# The difference is: 29790.65453331975
#
# Original value: 52995 vs the predicted value: -18851.672515206774
# The difference is: 71846.67251520677
#
# Original value: 10995 vs the predicted value: -13575.866420154276
# The difference is: 24570.866420154278
#
# Original value: 52995 vs the predicted value: -18709.66532641149
# The difference is: 71704.66532641149
#
# Original value: 23995 vs the predicted value: -17880.32203314363
# The difference is: 41875.32203314363
#
# Original value: 17200 vs the predicted value: -13035.906154341268
# The difference is: 30235.906154341268
#
# Original value: 15998 vs the predicted value: -13739.13040337601
# The difference is: 29737.13040337601
#
# Original value: 19495 vs the predicted value: -17964.968734915878
# The difference is: 37459.96873491588
#
# Original value: 24985 vs the predicted value: -15993.495294443237
# The difference is: 40978.49529444324
#
# Original value: 16400 vs the predicted value: -16519.411302617264
# The difference is: 32919.41130261726
